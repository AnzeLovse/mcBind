# %%
# Generates a list of commands that were run for model training.
from __future__ import print_function


protein_list = ["1_PARCLIP_AGO1234_hg19", "2_PARCLIP_AGO2MNASE_hg19", "3_HITSCLIP_Ago2_binding_clusters","4_HITSCLIP_Ago2_binding_clusters_2","5_CLIPSEQ_AGO2_hg19", "6_CLIP-seq-eIF4AIII_1","7_CLIP-seq-eIF4AIII_2","8_PARCLIP_ELAVL1_hg19","9_PARCLIP_ELAVL1MNASE_hg19", "10_PARCLIP_ELAVL1A_hg19", "10_PARCLIP_ELAVL1A_hg19", "12_PARCLIP_EWSR1_hg19", "13_PARCLIP_FUS_hg19", "14_PARCLIP_FUS_mut_hg19", "15_PARCLIP_IGF2BP123_hg19", "16_ICLIP_hnRNPC_Hela_iCLIP_all_clusters", "17_ICLIP_HNRNPC_hg19", "18_ICLIP_hnRNPL_Hela_group_3975_all-hnRNPL-Hela-hg19_sum_G_hg19--ensembl59_from_2337-2339-741_bedGraph-cDNA-hits-in-genome", "19_ICLIP_hnRNPL_U266_group_3986_all-hnRNPL-U266-hg19_sum_G_hg19--ensembl59_from_2485_bedGraph-cDNA-hits-in-genome", "20_ICLIP_hnRNPlike_U266_group_4000_all-hnRNPLlike-U266-hg19_sum_G_hg19--ensembl59_from_2342-2486_bedGraph-cDNA-hits-in-genome", "21_PARCLIP_MOV10_Sievers_hg19", "22_ICLIP_NSUN2_293_group_4007_all-NSUN2-293-hg19_sum_G_hg19--ensembl59_from_3137-3202_bedGraph-cDNA-hits-in-genome", "23_PARCLIP_PUM2_hg19", "24_PARCLIP_QKI_hg19", "25_CLIPSEQ_SFRS1_hg19","26_PARCLIP_TAF15_hg19", "27_ICLIP_TDP43_hg19", "28_ICLIP_TIA1_hg19", "29_ICLIP_TIAL1_hg19", "30_ICLIP_U2AF65_Hela_iCLIP_ctrl_all_clusters", "31_ICLIP_U2AF65_Hela_iCLIP_ctrl+kd_all_clusters"]
for i in range (3):
    for protein in protein_list:
        print (' python ideep.py --train=True --data_dir=datasets/clip/%s/30000/training_sample_%s/ --model_dir=models_%s/%s;' % (protein,i,i,protein),end='' )
# Out:
#  python ideep.py --train=True --data_dir=datasets/clip/1_PARCLIP_AGO1234_hg19/30000/training_sample_0/ --model_dir=models_0/1_PARCLIP_AGO1234_hg19; python ideep.py --train=True --data_dir=datasets/clip/2_PARCLIP_AGO2MNASE_hg19/30000/training_sample_0/ --model_dir=models_0/2_PARCLIP_AGO2MNASE_hg19; python ideep.py --train=True --data_dir=datasets/clip/3_HITSCLIP_Ago2_binding_clusters/30000/training_sample_0/ --model_dir=models_0/3_HITSCLIP_Ago2_binding_clusters; python ideep.py --train=True --data_dir=datasets/clip/4_HITSCLIP_Ago2_binding_clusters_2/30000/training_sample_0/ --model_dir=models_0/4_HITSCLIP_Ago2_binding_clusters_2; python ideep.py --train=True --data_dir=datasets/clip/5_CLIPSEQ_AGO2_hg19/30000/training_sample_0/ --model_dir=models_0/5_CLIPSEQ_AGO2_hg19; python ideep.py --train=True --data_dir=datasets/clip/6_CLIP-seq-eIF4AIII_1/30000/training_sample_0/ --model_dir=models_0/6_CLIP-seq-eIF4AIII_1; python ideep.py --train=True --data_dir=datasets/clip/7_CLIP-seq-eIF4AIII_2/30000/training_sample_0/ --model_dir=models_0/7_CLIP-seq-eIF4AIII_2; python ideep.py --train=True --data_dir=datasets/clip/8_PARCLIP_ELAVL1_hg19/30000/training_sample_0/ --model_dir=models_0/8_PARCLIP_ELAVL1_hg19; python ideep.py --train=True --data_dir=datasets/clip/9_PARCLIP_ELAVL1MNASE_hg19/30000/training_sample_0/ --model_dir=models_0/9_PARCLIP_ELAVL1MNASE_hg19; python ideep.py --train=True --data_dir=datasets/clip/10_PARCLIP_ELAVL1A_hg19/30000/training_sample_0/ --model_dir=models_0/10_PARCLIP_ELAVL1A_hg19; python ideep.py --train=True --data_dir=datasets/clip/10_PARCLIP_ELAVL1A_hg19/30000/training_sample_0/ --model_dir=models_0/10_PARCLIP_ELAVL1A_hg19; python ideep.py --train=True --data_dir=datasets/clip/12_PARCLIP_EWSR1_hg19/30000/training_sample_0/ --model_dir=models_0/12_PARCLIP_EWSR1_hg19; python ideep.py --train=True --data_dir=datasets/clip/13_PARCLIP_FUS_hg19/30000/training_sample_0/ --model_dir=models_0/13_PARCLIP_FUS_hg19; python ideep.py --train=True --data_dir=datasets/clip/14_PARCLIP_FUS_mut_hg19/30000/training_sample_0/ --model_dir=models_0/14_PARCLIP_FUS_mut_hg19; python ideep.py --train=True --data_dir=datasets/clip/15_PARCLIP_IGF2BP123_hg19/30000/training_sample_0/ --model_dir=models_0/15_PARCLIP_IGF2BP123_hg19; python ideep.py --train=True --data_dir=datasets/clip/16_ICLIP_hnRNPC_Hela_iCLIP_all_clusters/30000/training_sample_0/ --model_dir=models_0/16_ICLIP_hnRNPC_Hela_iCLIP_all_clusters; python ideep.py --train=True --data_dir=datasets/clip/17_ICLIP_HNRNPC_hg19/30000/training_sample_0/ --model_dir=models_0/17_ICLIP_HNRNPC_hg19; python ideep.py --train=True --data_dir=datasets/clip/18_ICLIP_hnRNPL_Hela_group_3975_all-hnRNPL-Hela-hg19_sum_G_hg19--ensembl59_from_2337-2339-741_bedGraph-cDNA-hits-in-genome/30000/training_sample_0/ --model_dir=models_0/18_ICLIP_hnRNPL_Hela_group_3975_all-hnRNPL-Hela-hg19_sum_G_hg19--ensembl59_from_2337-2339-741_bedGraph-cDNA-hits-in-genome; python ideep.py --train=True --data_dir=datasets/clip/19_ICLIP_hnRNPL_U266_group_3986_all-hnRNPL-U266-hg19_sum_G_hg19--ensembl59_from_2485_bedGraph-cDNA-hits-in-genome/30000/training_sample_0/ --model_dir=models_0/19_ICLIP_hnRNPL_U266_group_3986_all-hnRNPL-U266-hg19_sum_G_hg19--ensembl59_from_2485_bedGraph-cDNA-hits-in-genome; python ideep.py --train=True --data_dir=datasets/clip/20_ICLIP_hnRNPlike_U266_group_4000_all-hnRNPLlike-U266-hg19_sum_G_hg19--ensembl59_from_2342-2486_bedGraph-cDNA-hits-in-genome/30000/training_sample_0/ --model_dir=models_0/20_ICLIP_hnRNPlike_U266_group_4000_all-hnRNPLlike-U266-hg19_sum_G_hg19--ensembl59_from_2342-2486_bedGraph-cDNA-hits-in-genome; python ideep.py --train=True --data_dir=datasets/clip/21_PARCLIP_MOV10_Sievers_hg19/30000/training_sample_0/ --model_dir=models_0/21_PARCLIP_MOV10_Sievers_hg19; python ideep.py --train=True --data_dir=datasets/clip/22_ICLIP_NSUN2_293_group_4007_all-NSUN2-293-hg19_sum_G_hg19--ensembl59_from_3137-3202_bedGraph-cDNA-hits-in-genome/30000/training_sample_0/ --model_dir=models_0/22_ICLIP_NSUN2_29 ...

# %%
# Generates a list of commands that were run for generating predictions.
from __future__ import print_function


protein_list = ["1_PARCLIP_AGO1234_hg19", "2_PARCLIP_AGO2MNASE_hg19","3_HITSCLIP_Ago2_binding_clusters","4_HITSCLIP_Ago2_binding_clusters_2","5_CLIPSEQ_AGO2_hg19", "6_CLIP-seq-eIF4AIII_1","7_CLIP-seq-eIF4AIII_2","8_PARCLIP_ELAVL1_hg19","9_PARCLIP_ELAVL1MNASE_hg19", "10_PARCLIP_ELAVL1A_hg19", "10_PARCLIP_ELAVL1A_hg19", "12_PARCLIP_EWSR1_hg19", "13_PARCLIP_FUS_hg19", "14_PARCLIP_FUS_mut_hg19", "15_PARCLIP_IGF2BP123_hg19", "16_ICLIP_hnRNPC_Hela_iCLIP_all_clusters", "17_ICLIP_HNRNPC_hg19", "18_ICLIP_hnRNPL_Hela_group_3975_all-hnRNPL-Hela-hg19_sum_G_hg19--ensembl59_from_2337-2339-741_bedGraph-cDNA-hits-in-genome", "19_ICLIP_hnRNPL_U266_group_3986_all-hnRNPL-U266-hg19_sum_G_hg19--ensembl59_from_2485_bedGraph-cDNA-hits-in-genome", "20_ICLIP_hnRNPlike_U266_group_4000_all-hnRNPLlike-U266-hg19_sum_G_hg19--ensembl59_from_2342-2486_bedGraph-cDNA-hits-in-genome", "21_PARCLIP_MOV10_Sievers_hg19", "22_ICLIP_NSUN2_293_group_4007_all-NSUN2-293-hg19_sum_G_hg19--ensembl59_from_3137-3202_bedGraph-cDNA-hits-in-genome", "23_PARCLIP_PUM2_hg19", "24_PARCLIP_QKI_hg19", "25_CLIPSEQ_SFRS1_hg19","26_PARCLIP_TAF15_hg19", "27_ICLIP_TDP43_hg19", "28_ICLIP_TIA1_hg19", "29_ICLIP_TIAL1_hg19", "30_ICLIP_U2AF65_Hela_iCLIP_ctrl_all_clusters", "31_ICLIP_U2AF65_Hela_iCLIP_ctrl+kd_all_clusters"]
for i in range (3):
    for protein in protein_list:
        print (' python ideep.py --predict=True --data_dir=datasets/clip/%s/30000/test_sample_%s/ --model_dir=models%s/%s --out_file=predictions_%s/%s; ' % (protein,i,i,protein,i,protein),end='' )
# Out:
#  python ideep.py --predict=True --data_dir=datasets/clip/1_PARCLIP_AGO1234_hg19/30000/test_sample_0/ --model_dir=models0/1_PARCLIP_AGO1234_hg19 --out_file=predictions_0/1_PARCLIP_AGO1234_hg19;  python ideep.py --predict=True --data_dir=datasets/clip/2_PARCLIP_AGO2MNASE_hg19/30000/test_sample_0/ --model_dir=models0/2_PARCLIP_AGO2MNASE_hg19 --out_file=predictions_0/2_PARCLIP_AGO2MNASE_hg19;  python ideep.py --predict=True --data_dir=datasets/clip/3_HITSCLIP_Ago2_binding_clusters/30000/test_sample_0/ --model_dir=models0/3_HITSCLIP_Ago2_binding_clusters --out_file=predictions_0/3_HITSCLIP_Ago2_binding_clusters;  python ideep.py --predict=True --data_dir=datasets/clip/4_HITSCLIP_Ago2_binding_clusters_2/30000/test_sample_0/ --model_dir=models0/4_HITSCLIP_Ago2_binding_clusters_2 --out_file=predictions_0/4_HITSCLIP_Ago2_binding_clusters_2;  python ideep.py --predict=True --data_dir=datasets/clip/5_CLIPSEQ_AGO2_hg19/30000/test_sample_0/ --model_dir=models0/5_CLIPSEQ_AGO2_hg19 --out_file=predictions_0/5_CLIPSEQ_AGO2_hg19;  python ideep.py --predict=True --data_dir=datasets/clip/6_CLIP-seq-eIF4AIII_1/30000/test_sample_0/ --model_dir=models0/6_CLIP-seq-eIF4AIII_1 --out_file=predictions_0/6_CLIP-seq-eIF4AIII_1;  python ideep.py --predict=True --data_dir=datasets/clip/7_CLIP-seq-eIF4AIII_2/30000/test_sample_0/ --model_dir=models0/7_CLIP-seq-eIF4AIII_2 --out_file=predictions_0/7_CLIP-seq-eIF4AIII_2;  python ideep.py --predict=True --data_dir=datasets/clip/8_PARCLIP_ELAVL1_hg19/30000/test_sample_0/ --model_dir=models0/8_PARCLIP_ELAVL1_hg19 --out_file=predictions_0/8_PARCLIP_ELAVL1_hg19;  python ideep.py --predict=True --data_dir=datasets/clip/9_PARCLIP_ELAVL1MNASE_hg19/30000/test_sample_0/ --model_dir=models0/9_PARCLIP_ELAVL1MNASE_hg19 --out_file=predictions_0/9_PARCLIP_ELAVL1MNASE_hg19;  python ideep.py --predict=True --data_dir=datasets/clip/10_PARCLIP_ELAVL1A_hg19/30000/test_sample_0/ --model_dir=models0/10_PARCLIP_ELAVL1A_hg19 --out_file=predictions_0/10_PARCLIP_ELAVL1A_hg19;  python ideep.py --predict=True --data_dir=datasets/clip/10_PARCLIP_ELAVL1A_hg19/30000/test_sample_0/ --model_dir=models0/10_PARCLIP_ELAVL1A_hg19 --out_file=predictions_0/10_PARCLIP_ELAVL1A_hg19;  python ideep.py --predict=True --data_dir=datasets/clip/12_PARCLIP_EWSR1_hg19/30000/test_sample_0/ --model_dir=models0/12_PARCLIP_EWSR1_hg19 --out_file=predictions_0/12_PARCLIP_EWSR1_hg19;  python ideep.py --predict=True --data_dir=datasets/clip/13_PARCLIP_FUS_hg19/30000/test_sample_0/ --model_dir=models0/13_PARCLIP_FUS_hg19 --out_file=predictions_0/13_PARCLIP_FUS_hg19;  python ideep.py --predict=True --data_dir=datasets/clip/14_PARCLIP_FUS_mut_hg19/30000/test_sample_0/ --model_dir=models0/14_PARCLIP_FUS_mut_hg19 --out_file=predictions_0/14_PARCLIP_FUS_mut_hg19;  python ideep.py --predict=True --data_dir=datasets/clip/15_PARCLIP_IGF2BP123_hg19/30000/test_sample_0/ --model_dir=models0/15_PARCLIP_IGF2BP123_hg19 --out_file=predictions_0/15_PARCLIP_IGF2BP123_hg19;  python ideep.py --predict=True --data_dir=datasets/clip/16_ICLIP_hnRNPC_Hela_iCLIP_all_clusters/30000/test_sample_0/ --model_dir=models0/16_ICLIP_hnRNPC_Hela_iCLIP_all_clusters --out_file=predictions_0/16_ICLIP_hnRNPC_Hela_iCLIP_all_clusters;  python ideep.py --predict=True --data_dir=datasets/clip/17_ICLIP_HNRNPC_hg19/30000/test_sample_0/ --model_dir=models0/17_ICLIP_HNRNPC_hg19 --out_file=predictions_0/17_ICLIP_HNRNPC_hg19;  python ideep.py --predict=True --data_dir=datasets/clip/18_ICLIP_hnRNPL_Hela_group_3975_all-hnRNPL-Hela-hg19_sum_G_hg19--ensembl59_from_2337-2339-741_bedGraph-cDNA-hits-in-genome/30000/test_sample_0/ --model_dir=models0/18_ICLIP_hnRNPL_Hela_group_3975_all-hnRNPL-Hela-hg19_sum_G_hg19--ensembl59_from_2337-2339-741_bedGraph-cDNA-hits-in-genome --out_file=predictions_0/18_ICLIP_hnRNPL_Hela_group_3975_all-hnRNPL-Hela-hg19_sum_G_hg19--ensembl59_from_2337-2339-741_bedGraph-cDNA-hits-in-genome;  python ideep.py --predict=True --data_dir=datasets/clip/19_ICLIP_hnRNPL_U266_group_3986_all-hnRNPL-U266-hg19 ...

# %%
#Evaluating iDeep
import numpy as np
import gzip
import os
from Bio import SeqIO
from sklearn.metrics import roc_auc_score, roc_curve


def load_data(path):
    data = gzip.open(os.path.join(path,"sequences.fa.gz"),"rt")
    return data


def get_class(protein, t_data,training_set_number):
    y_train = []
    if t_data == 'train':
        data = load_data("datasets/clip/%s/30000/training_sample_%s"% (protein, training_set_number))
    elif t_data == 'test':
        data = load_data("datasets/clip/%s/30000/test_sample_%s"% (protein, training_set_number))
    for record in SeqIO.parse(data,"fasta"):
        v = int((record.description).split(":")[1])
        # [1,0] if there was no observed binding and [0,1] for sequences where binding was observed.
        y_train.append([int(v == 0), int(v != 0)])
    return np.array(y_train)


protein_list = ["1_PARCLIP_AGO1234_hg19", "2_PARCLIP_AGO2MNASE_hg19","3_HITSCLIP_Ago2_binding_clusters","4_HITSCLIP_Ago2_binding_clusters_2","5_CLIPSEQ_AGO2_hg19", "6_CLIP-seq-eIF4AIII_1","7_CLIP-seq-eIF4AIII_2","8_PARCLIP_ELAVL1_hg19","9_PARCLIP_ELAVL1MNASE_hg19", "10_PARCLIP_ELAVL1A_hg19", "10_PARCLIP_ELAVL1A_hg19", "12_PARCLIP_EWSR1_hg19", "13_PARCLIP_FUS_hg19", "14_PARCLIP_FUS_mut_hg19", "15_PARCLIP_IGF2BP123_hg19", "16_ICLIP_hnRNPC_Hela_iCLIP_all_clusters", "17_ICLIP_HNRNPC_hg19", "18_ICLIP_hnRNPL_Hela_group_3975_all-hnRNPL-Hela-hg19_sum_G_hg19--ensembl59_from_2337-2339-741_bedGraph-cDNA-hits-in-genome", "19_ICLIP_hnRNPL_U266_group_3986_all-hnRNPL-U266-hg19_sum_G_hg19--ensembl59_from_2485_bedGraph-cDNA-hits-in-genome", "20_ICLIP_hnRNPlike_U266_group_4000_all-hnRNPLlike-U266-hg19_sum_G_hg19--ensembl59_from_2342-2486_bedGraph-cDNA-hits-in-genome", "21_PARCLIP_MOV10_Sievers_hg19", "22_ICLIP_NSUN2_293_group_4007_all-NSUN2-293-hg19_sum_G_hg19--ensembl59_from_3137-3202_bedGraph-cDNA-hits-in-genome", "23_PARCLIP_PUM2_hg19", "24_PARCLIP_QKI_hg19", "25_CLIPSEQ_SFRS1_hg19","26_PARCLIP_TAF15_hg19", "27_ICLIP_TDP43_hg19", "28_ICLIP_TIA1_hg19", "29_ICLIP_TIAL1_hg19", "30_ICLIP_U2AF65_Hela_iCLIP_ctrl_all_clusters", "31_ICLIP_U2AF65_Hela_iCLIP_ctrl+kd_all_clusters"]
score_dict = {}
for training_set_number in range(3):
    score_list = []
    for protein in protein_list:
        # Load predictions for a specific protein dataset. 
        predictions = np.loadtxt("ideep_results/predictions%s/%s" %(training_set_number, protein), delimiter="\n", unpack=False)
        predictions = np.array(predictions)
        # Load true classes for model evaluation.
        Y_test =  get_class(protein, "test", training_set_number)
        Y_test = Y_test[:,1]
        score = roc_auc_score(Y_test, predictions)


        score_list.append(score)
    score_dict[training_set_number] = score_list
print (np.true_divide(np.add(score_dict[0],(np.add(score_dict[1], score_dict[2]))),3))
# Out:
# [0.93668944 0.76282461 0.94159092 0.94483924 0.76107508 0.95504916
#  0.97001479 0.96485094 0.76609511 0.9469512  0.9469512  0.9525081
#  0.94539888 0.98648477 0.95614971 0.94825049 0.96873706 0.84875831
#  0.82395875 0.82983874 0.97112416 0.88624311 0.98298004 0.96877799
#  0.92754448 0.97679184 0.91218175 0.94829456 0.9227082  0.95288192
#  0.94209036]
