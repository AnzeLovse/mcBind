# %%
import pandas as pd
import numpy as np


def highlight_max(s):
    """Marks the series in bold."""
    is_max = s == s.max()
    return ['font-weight:bold' if v else '' for v in is_max]

def latex_highlight(x):
    is_max = x == x.max()
    return [f'\\textbf{{{np.round(val, 2)}}}' if v else np.round(val, 2) for val, v in zip(x, is_max)]

ionmf = [0.9, 0.69, 0.82, 0.81, 0.65, 0.84, 0.89, 0.81, 0.66, 0.94, 0.93, 0.82, 0.59, 0.92, 0.91,
         0.62, 0.61, 0.76, 0.63, 0.71, 0.96, 0.77, 0.91, 0.58, 0.84, 0.86, 0.61, 0.87, 0.8, 0.67, 0.66]
ideep = [0.93668944, 0.76282461, 0.94159092, 0.94483924, 0.76107508, 0.95504916,
         0.97001479, 0.96485094, 0.76609511, 0.9469512,  0.9469512,  0.9525081,
         0.94539888, 0.98648477, 0.95614971, 0.94825049, 0.96873706, 0.84875831,
         0.82395875, 0.82983874, 0.97112416, 0.88624311, 0.98298004, 0.96877799,
         0.92754448, 0.97679184, 0.91218175, 0.94829456, 0.9227082,  0.95288192,
         0.94209036]
new = [0.9392143229166666, 0.7524039895833333, 0.9369149270833333, 0.9400964583333332,
       0.76447290625, 0.9531564895833333, 0.9787366458333334, 0.9694093333333332,
       0.7520650416666665, 0.9510720729166667, 0.9510720729166667, 0.9596307708333334,
       0.9471521770833333, 0.9911667291666667, 0.9552266145833334, 0.9577844479166666,
       0.9722244062500001, 0.8538024375000001, 0.7888937604166667, 0.7975334687500001,
       0.9769656875, 0.8685512083333333, 0.9880345729166667, 0.9792528645833333,
       0.9225929270833332, 0.9818128645833334, 0.9160058958333335, 0.9735055729166667,
       0.9438058020833333, 0.9438112291666667, 0.9369199270833333]
protein_list = ["1_PARCLIP_AGO1234_hg19", "2_PARCLIP_AGO2MNASE_hg19", "3_HITSCLIP_Ago2_binding_clusters", "4_HITSCLIP_Ago2_binding_clusters_2", "5_CLIPSEQ_AGO2_hg19", "6_CLIP-seq-eIF4AIII_1", "7_CLIP-seq-eIF4AIII_2", "8_PARCLIP_ELAVL1_hg19", "9_PARCLIP_ELAVL1MNASE_hg19", "10_PARCLIP_ELAVL1A_hg19", "10_PARCLIP_ELAVL1A_hg19", "12_PARCLIP_EWSR1_hg19", "13_PARCLIP_FUS_hg19", "14_PARCLIP_FUS_mut_hg19", "15_PARCLIP_IGF2BP123_hg19", "16_ICLIP_hnRNPC_Hela_iCLIP_all_clusters", "17_ICLIP_HNRNPC_hg19", "18_ICLIP_hnRNPL_Hela_group_3975_all-hnRNPL-Hela-hg19_sum_G_hg19--ensembl59_from_2337-2339-741_bedGraph-cDNA-hits-in-genome",
                "19_ICLIP_hnRNPL_U266_group_3986_all-hnRNPL-U266-hg19_sum_G_hg19--ensembl59_from_2485_bedGraph-cDNA-hits-in-genome", "20_ICLIP_hnRNPlike_U266_group_4000_all-hnRNPLlike-U266-hg19_sum_G_hg19--ensembl59_from_2342-2486_bedGraph-cDNA-hits-in-genome", "21_PARCLIP_MOV10_Sievers_hg19", "22_ICLIP_NSUN2_293_group_4007_all-NSUN2-293-hg19_sum_G_hg19--ensembl59_from_3137-3202_bedGraph-cDNA-hits-in-genome", "23_PARCLIP_PUM2_hg19", "24_PARCLIP_QKI_hg19", "25_CLIPSEQ_SFRS1_hg19", "26_PARCLIP_TAF15_hg19", "27_ICLIP_TDP43_hg19", "28_ICLIP_TIA1_hg19", "29_ICLIP_TIAL1_hg19", "30_ICLIP_U2AF65_Hela_iCLIP_ctrl_all_clusters", "31_ICLIP_U2AF65_Hela_iCLIP_ctrl+kd_all_clusters"]
protein_list = ['1 Ago/EIF', '2 Ago2-MNase', '3 Ago2-1', '4 Ago2-2', '5 Ago2', '6 eIF4AIII-1', '7 eIF4AIII-2', '8 ELAVL1-1', '9 ELAVL1-MNase', '10 ELAVL1A', '11 ELAVL1-2', '12 ESWR1', '13 FUS', '14 Mut FUS', '15 IGFBP1-3',
                '16 hnRNPC-1', '17 hnRNPC-2', '18 hnRNPL-1', '19 hnRNPL-2', '20 hnRNPL-like', '21 MOV10', '22 Nsun2', '23 PUM2', '24 QKI', '25 SRSF1', '26 TAF15', '27 TDP-43', '28 TIA1', '29 TIAL1', '30 U2AF2', '31 U2AF2(KD)']

table_data = {'New': new, 'iDeep': ideep, 'iONMF': ionmf}

table = pd.DataFrame(table_data, index=protein_list)

d1 = np.subtract(new, ideep)
d2 = np.subtract(new, ionmf)

n1 = sum(1 for number in d1 if number > 0)
n2 = sum(1 for number in d2 if number > 0)

print("Mean difference with iDeep is %s " % (np.mean(d1)))
print("Number of proteins for which our model is better: %s " % (n1))
print("Mean difference with iONMF is %s " % (np.mean(d2)))
print("Number of proteins for which our model is better: %s " % (n2))


with pd.option_context('display.precision', 2):
    html = (table.style.apply(highlight_max, axis=1))
latex_table = table.apply(latex_highlight, axis=1, result_type='expand')

# print(latex_table.to_latex(escape=False))
html
# Out:
# Mean difference with iDeep is -0.0001724930645161266
# Number of proteins for which our model is better: 19
# Mean difference with iONMF is 0.14526734274193548
# Number of proteins for which our model is better: 31
# <style  type="text/css" >
#     #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow0_col0 {
#             font-weight: bold;
#         }    #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow1_col1 {
#             font-weight: bold;
#         }    #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow2_col1 {
#             font-weight: bold;
#         }    #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow3_col1 {
#             font-weight: bold;
#         }    #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow4_col0 {
#             font-weight: bold;
#         }    #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow5_col1 {
#             font-weight: bold;
#         }    #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow6_col0 {
#             font-weight: bold;
#         }    #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow7_col0 {
#             font-weight: bold;
#         }    #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow8_col1 {
#             font-weight: bold;
#         }    #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow9_col0 {
#             font-weight: bold;
#         }    #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow10_col0 {
#             font-weight: bold;
#         }    #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow11_col0 {
#             font-weight: bold;
#         }    #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow12_col0 {
#             font-weight: bold;
#         }    #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow13_col0 {
#             font-weight: bold;
#         }    #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow14_col1 {
#             font-weight: bold;
#         }    #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow15_col0 {
#             font-weight: bold;
#         }    #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow16_col0 {
#             font-weight: bold;
#         }    #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow17_col0 {
#             font-weight: bold;
#         }    #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow18_col1 {
#             font-weight: bold;
#         }    #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow19_col1 {
#             font-weight: bold;
#         }    #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow20_col0 {
#             font-weight: bold;
#         }    #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow21_col1 {
#             font-weight: bold;
#         }    #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow22_col0 {
#             font-weight: bold;
#         }    #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow23_col0 {
#             font-weight: bold;
#         }    #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow24_col1 {
#             font-weight: bold;
#         }    #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow25_col0 {
#             font-weight: bold;
#         }    #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow26_col0 {
#             font-weight: bold;
#         }    #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow27_col0 {
#             font-weight: bold;
#         }    #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow28_col0 {
#             font-weight: bold;
#         }    #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow29_col1 {
#             font-weight: bold;
#         }    #T_d3927882_24d9_11ea_ab0d_efc9d60f335erow30_col1 {
#             font-weight: bold;
#         }</style><table id="T_d3927882_24d9_11ea_ab0d_efc9d60f335e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >New</th>        <th class="col_heading level0 col1" >iDeep</th>        <th class="col_heading level0 col2" >iONMF</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d3927882_24d9_11ea_ab0d_efc9d60f335elevel0_row0" class="row_heading level0 row0" >1 Ago/EIF</th>
#                         <td id="T_d3927882_24d9_11ea_ab0d_efc9d60f335erow0_col0" class="data row0 col0" >0.94</td>
#                         <td id="T_d3927882_24d9_11ea_ab0d_efc9d60f335erow0_col1" class="data row0 col1" >0.94</td>
#                         <td id="T_d3927882_24d9_11ea_ab0d_efc9d60f335erow0_col2" class="data row0 col2" >0.9</td>
#             </tr>
#             <tr>
#                         <th id="T_d3927882_24d9_11ea_ab0d_efc9d60f335elevel0_row1" class="row_heading level0 row1" >2 Ago2-MNase</th>
#                         <td id="T_d3927882_24d9_11ea_ab0d_efc9d60f335erow1_col0" class="data row1 col0" >0.75</td>
#                         <td id="T_d3927882_24d9_11ea_ab0d_efc9d60f335erow1_col1" class="data row1 col1" >0.76</td>
#                         <td id="T_d3927882_24d9_11ea_ab0d_efc9d60f335erow1_col2" class="data row1 col2" >0.69</td>
#             </tr>
#             <tr>
#                         <th id="T_d3927882_24d9_11ea_ab0d_efc9d60f335elevel0_row2" class="row_heading level0 row2" >3 Ago2-1</th>
#                         <td id="T_d3927882_24d9_11ea_ab0d_efc9d60f335erow2_col0" class="data row2 col0" >0.94</td>
#                         <td id="T_d3927882_24d9_11ea_ab0d_efc9d60f335erow2_col1" class="data row2 col1" >0.94</td>
#                         <td id="T_d3927882_24d9_11ea_ab0d_efc9d60f335erow2_col2" class="data row2 col2" >0.82</td>
#             </tr>
#             <tr>
#                         <th id="T_d3927882_24d9_11ea_ab0d_efc9d60f335elevel0_row3" class="row_heading level0 row3" >4 Ago2-2</th>
#                         <td id="T_d3927882_24d9_11ea_ab0d_efc9d60f335erow3_col0" class="data row3 col0" >0.94</td>
#                         <td id="T_d3927882_24d9_11ea_ab0d_efc9d60f335erow3_col1" class="data row3 col1" >0.94</td>
#                         <td id="T_d3927882_24d9_11ea_ab0d_efc9d60f335erow3_col2" class="data row3 col2" >0.81</td>
#             </tr>
#             <tr>
#                         <th id="T_d3927882_24d9_11ea_ab0d_efc9d60f335elevel0_row4" class="row_heading level0 row4" >5 Ago2</th>
#                         <td id="T_d3927882_24d9_11ea_ab0d_efc9d60f335erow4_col0" class="data row4 col0" >0.76</td>
#                         <td id="T_d3927882_24d9_11ea_ab0d_efc9d60f335erow4_col1" class="data row4 col1" >0.76</td>
#                         <td id="T_d3927882_24d9_11ea_ab0d_efc9d60f335erow4_col2" class="data row4 col2" >0.65</td>
#             </tr>
#             <tr>
#                         <th id="T_d3927882_24d9_11ea_ab0d_efc9d60f335elevel0_row5" class="row_heading level0 row5" >6 eIF4AIII-1</th>
#                         <td id="T_d3927882_24d9_11ea_ab0d_efc9d60f335erow5_col0" class="data row5 col0" >0.95</td>
#                         <td id="T_d3927882_24d9_11ea_ab0d_efc9d60f335erow5_col1" class="data row5 col1" >0.96</td>
#                         <td id="T_d3927882_24d9_11ea_ab0d_efc9d60f335erow5_col2" class="data row5 col2" >0.84</td>
#             </tr>
#             <tr>
#                         <th id="T_d3927882_24d9_11ea_ab0d_efc9d60f335elevel0_row6" class="row_heading level0 row6" >7 eIF4AIII-2</th>
#                         <td id="T_d3927882_24d9_11ea_ab0d_efc9d60f335erow6_col0" class="data row6 col0" >0.98</td>
#                         <td id="T_d3927882_24d9_11ea_ab0d_efc9d60f335erow6_col1" class="data row6 col1" >0.97</td>
#                         <td id="T_d3927882_24d9_11ea_ab0d_efc9d60f335erow6_col2" class="data row6 col2" >0.89</td>
#             </tr>
#             <tr>
#                         <th id="T_d3927882_24d9_11ea_ab0d_efc9d60f335elevel0_row7" class="row_heading level0 row7" >8 ELAVL1-1</th>
#                         <td id="T_d3927882_24d9_11ea_ab0d_efc9d60f335erow7_col0" class="data row7 col0" >0.97</td>
#                         <td id="T_d3927882_24d9_11ea_ab0d_efc9d60f335erow7_col1" class="data row7 col1" >0.96</td>
#                         <td id="T_d3927882_24d9_11ea_ab0d_efc9d60f335erow7_col2" class="data row7 col2" >0.81</td>
#             </tr>
#             <tr>
#                         <th id="T_d3927882_24d9_11ea_ab0d_efc9d60f335elevel0_row8" class="row_heading level0 row8" >9 ELAVL1-MNase</th>
#                         <td id="T_d3927882_24d9_11ea_ab0d_efc9d60f335erow8_col0" class="data row8 col0" >0.75</td>
#                         <td id="T_d3927882_24d9_11ea_ab0d_efc9d60f335erow8_col1" class="data row8 col1" >0.77</td>
#                         <td id="T_d3927882_24d9_11ea_ab0d_efc9d60f335erow8_col2" class="data row8 col2" >0.66</td>
#             </tr>
#             <tr>
#                         <th id="T_d3927882_24d9_11ea_ab0d_efc9d60f335elevel0_

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(8, 1, sharex=True, figsize=(20,4))
receptive_field = 0
receptive_field_previous = 1
filters = [6,20,4,40,4,30,3]
layers = ['conv1','pool1','conv2','pool2','conv3','pool3','conv4']

img = np.full((1, 101, 3), 255, dtype=int)
img[:, 0, 0] = 200
img[:, 0, 1] = 255
img[:, 0, 2] = 255
axes[0].imshow(img, aspect='equal')
axes[0].set_xticks(np.arange(-0.5, 101), minor=True)
axes[0].set_yticks(np.arange(0))
axes[0].grid(which='minor', color='black', linestyle='-', linewidth=0.2)

for i, filter_size in enumerate(filters):
    receptive_field = receptive_field_previous + filter_size - 1
    print('ERF of layer {} is {}'.format(layers[i], receptive_field))
    receptive_field_previous = receptive_field
    
#     fig, ax = plt.subplots(figsize=(20,4))
    img = np.full((1, 101, 3), 255, dtype=int)
    for pos in range(receptive_field):
        img[:, pos, 0] = 200
        img[:, pos, 1] = 255
        img[:, pos, 2] = 255
    axes[i+1].imshow(img, aspect='equal')
    axes[i+1].set_xticks(np.arange(-0.5, 101), minor=True)
    axes[i+1].set_yticks(np.arange(0))
    axes[i+1].grid(which='minor', color='black', linestyle='-', linewidth=0.2)

plt.show()
# Out:
# ERF of layer conv1 is 6
# ERF of layer pool1 is 25
# ERF of layer conv2 is 28
# ERF of layer pool2 is 67
# ERF of layer conv3 is 70
# ERF of layer pool3 is 99
# ERF of layer conv4 is 101

# %%
import numpy as np
protein_list = ["1_PARCLIP_AGO1234_hg19", "2_PARCLIP_AGO2MNASE_hg19","3_HITSCLIP_Ago2_binding_clusters","4_HITSCLIP_Ago2_binding_clusters_2","5_CLIPSEQ_AGO2_hg19", "6_CLIP-seq-eIF4AIII_1","7_CLIP-seq-eIF4AIII_2","8_PARCLIP_ELAVL1_hg19","9_PARCLIP_ELAVL1MNASE_hg19", "10_PARCLIP_ELAVL1A_hg19", "10_PARCLIP_ELAVL1A_hg19", "12_PARCLIP_EWSR1_hg19", "13_PARCLIP_FUS_hg19", "14_PARCLIP_FUS_mut_hg19", "15_PARCLIP_IGF2BP123_hg19", "16_ICLIP_hnRNPC_Hela_iCLIP_all_clusters", "17_ICLIP_HNRNPC_hg19", "18_ICLIP_hnRNPL_Hela_group_3975_all-hnRNPL-Hela-hg19_sum_G_hg19--ensembl59_from_2337-2339-741_bedGraph-cDNA-hits-in-genome", "19_ICLIP_hnRNPL_U266_group_3986_all-hnRNPL-U266-hg19_sum_G_hg19--ensembl59_from_2485_bedGraph-cDNA-hits-in-genome", "20_ICLIP_hnRNPlike_U266_group_4000_all-hnRNPLlike-U266-hg19_sum_G_hg19--ensembl59_from_2342-2486_bedGraph-cDNA-hits-in-genome", "21_PARCLIP_MOV10_Sievers_hg19", "22_ICLIP_NSUN2_293_group_4007_all-NSUN2-293-hg19_sum_G_hg19--ensembl59_from_3137-3202_bedGraph-cDNA-hits-in-genome", "23_PARCLIP_PUM2_hg19", "24_PARCLIP_QKI_hg19", "25_CLIPSEQ_SFRS1_hg19","26_PARCLIP_TAF15_hg19", "27_ICLIP_TDP43_hg19", "28_ICLIP_TIA1_hg19", "29_ICLIP_TIAL1_hg19", "30_ICLIP_U2AF65_Hela_iCLIP_ctrl_all_clusters", "31_ICLIP_U2AF65_Hela_iCLIP_ctrl+kd_all_clusters"]
new = [0.94, 0.75, 0.94, 0.94, 0.76, 0.95, 0.98, 0.97, 0.75, 0.95, 0.95, 0.96, 0.95, 0.99, 0.96, 0.96, 0.97, 0.85, 0.79, 0.8, 0.98, 0.87, 0.99, 0.98, 0.92, 0.98, 0.92, 0.97, 0.94, 0.94, 0.94]
max_value = max(new)
max_protein = [protein_list[i] for i, j in enumerate(new) if j == max_value]
print (max_value, max_protein)

min_value = min(new)
min_protein = [protein_list[i] for i, j in enumerate(new) if j == min_value]
print (min_value, min_protein)

low_protein = [protein_list[i] for i, j in enumerate(new) if j > 0.9]
print (len(low_protein))
print (np.average(new))
# Out:
# (0.99, ['14_PARCLIP_FUS_mut_hg19', '23_PARCLIP_PUM2_hg19'])
# (0.75, ['2_PARCLIP_AGO2MNASE_hg19', '9_PARCLIP_ELAVL1MNASE_hg19'])
# 24
# 0.9206451612903228

# %%
from keras.models import model_from_json
from keras.utils import plot_model


protein_list = ["1_PARCLIP_AGO1234_hg19", "2_PARCLIP_AGO2MNASE_hg19","3_HITSCLIP_Ago2_binding_clusters","4_HITSCLIP_Ago2_binding_clusters_2","5_CLIPSEQ_AGO2_hg19", "6_CLIP-seq-eIF4AIII_1","7_CLIP-seq-eIF4AIII_2","8_PARCLIP_ELAVL1_hg19","9_PARCLIP_ELAVL1MNASE_hg19", "10_PARCLIP_ELAVL1A_hg19", "10_PARCLIP_ELAVL1A_hg19", "12_PARCLIP_EWSR1_hg19", "13_PARCLIP_FUS_hg19", "14_PARCLIP_FUS_mut_hg19", "15_PARCLIP_IGF2BP123_hg19", "16_ICLIP_hnRNPC_Hela_iCLIP_all_clusters", "17_ICLIP_HNRNPC_hg19", "18_ICLIP_hnRNPL_Hela_group_3975_all-hnRNPL-Hela-hg19_sum_G_hg19--ensembl59_from_2337-2339-741_bedGraph-cDNA-hits-in-genome", "19_ICLIP_hnRNPL_U266_group_3986_all-hnRNPL-U266-hg19_sum_G_hg19--ensembl59_from_2485_bedGraph-cDNA-hits-in-genome", "20_ICLIP_hnRNPlike_U266_group_4000_all-hnRNPLlike-U266-hg19_sum_G_hg19--ensembl59_from_2342-2486_bedGraph-cDNA-hits-in-genome", "21_PARCLIP_MOV10_Sievers_hg19", "22_ICLIP_NSUN2_293_group_4007_all-NSUN2-293-hg19_sum_G_hg19--ensembl59_from_3137-3202_bedGraph-cDNA-hits-in-genome", "23_PARCLIP_PUM2_hg19", "24_PARCLIP_QKI_hg19", "25_CLIPSEQ_SFRS1_hg19","26_PARCLIP_TAF15_hg19", "27_ICLIP_TDP43_hg19", "28_ICLIP_TIA1_hg19", "29_ICLIP_TIAL1_hg19", "30_ICLIP_U2AF65_Hela_iCLIP_ctrl_all_clusters", "31_ICLIP_U2AF65_Hela_iCLIP_ctrl+kd_all_clusters"]
experiment_set = ['KMER' , 'RNA', 'RG', 'CLIP']
protein = "1_PARCLIP_AGO1234_hg19"
#Load the model and weights.
with open("results/set_%s/%s/model.json" % (0, protein), "r") as json_file:
    json = json_file.read()
    loaded_model = model_from_json(json)
    plot_model(loaded_model, show_shapes=True, to_file='model.png')
