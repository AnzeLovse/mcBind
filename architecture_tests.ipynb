protein_list = ["1_PARCLIP_AGO1234_hg19", "2_PARCLIP_AGO2MNASE_hg19","3_HITSCLIP_Ago2_binding_clusters","4_HITSCLIP_Ago2_binding_clusters_2","5_CLIPSEQ_AGO2_hg19", "6_CLIP-seq-eIF4AIII_1","7_CLIP-seq-eIF4AIII_2","8_PARCLIP_ELAVL1_hg19","9_PARCLIP_ELAVL1MNASE_hg19", "10_PARCLIP_ELAVL1A_hg19", "10_PARCLIP_ELAVL1A_hg19", "12_PARCLIP_EWSR1_hg19", "13_PARCLIP_FUS_hg19", "14_PARCLIP_FUS_mut_hg19", "15_PARCLIP_IGF2BP123_hg19", "16_ICLIP_hnRNPC_Hela_iCLIP_all_clusters", "17_ICLIP_HNRNPC_hg19", "18_ICLIP_hnRNPL_Hela_group_3975_all-hnRNPL-Hela-hg19_sum_G_hg19--ensembl59_from_2337-2339-741_bedGraph-cDNA-hits-in-genome", "19_ICLIP_hnRNPL_U266_group_3986_all-hnRNPL-U266-hg19_sum_G_hg19--ensembl59_from_2485_bedGraph-cDNA-hits-in-genome", "20_ICLIP_hnRNPlike_U266_group_4000_all-hnRNPLlike-U266-hg19_sum_G_hg19--ensembl59_from_2342-2486_bedGraph-cDNA-hits-in-genome", "21_PARCLIP_MOV10_Sievers_hg19", "22_ICLIP_NSUN2_293_group_4007_all-NSUN2-293-hg19_sum_G_hg19--ensembl59_from_3137-3202_bedGraph-cDNA-hits-in-genome", "23_PARCLIP_PUM2_hg19", "24_PARCLIP_QKI_hg19", "25_CLIPSEQ_SFRS1_hg19","26_PARCLIP_TAF15_hg19", "27_ICLIP_TDP43_hg19", "28_ICLIP_TIA1_hg19", "29_ICLIP_TIAL1_hg19", "30_ICLIP_U2AF65_Hela_iCLIP_ctrl_all_clusters", "31_ICLIP_U2AF65_Hela_iCLIP_ctrl+kd_all_clusters"]
protein_list = np.arange(1,32,1)

              
table_data = {'KMER+RG+RNA':kmer_rg_rna,'KMER+CLIP+RNA': kmer_clip_rna,'RNA+RG':fold_rg, 'CLIP+RG': rg_cob,'KMER+RG':kmer_rg,'CLIP+RNA+RG':fold_cob_rg,'CLIP+RNA':fold_cob,'KMER+RNA':fold_seq,'RNA':fold,'RG': region, 'KMER' : score_seq, 'KMER+CLIP':score_cob, 'KMER+CLIP+RG':score_rg, 'KMER+CLIP+RG+RNA':score_fold,'CLIP':cobinding}

table = pd.DataFrame(table_data, index = protein_list)
table = table.T



#print (table)

# %%
table.style.apply(highlight_max)
# Out:
# <style  type="text/css" >
#     #T_578bbc94_d30e_11e8_b2b6_52540011a660row2_col1 {
#             background-color:  yellow;
#         }    #T_578bbc94_d30e_11e8_b2b6_52540011a660row4_col15 {
#             background-color:  yellow;
#         }    #T_578bbc94_d30e_11e8_b2b6_52540011a660row4_col26 {
#             background-color:  yellow;
#         }    #T_578bbc94_d30e_11e8_b2b6_52540011a660row5_col8 {
#             background-color:  yellow;
#         }    #T_578bbc94_d30e_11e8_b2b6_52540011a660row5_col18 {
#             background-color:  yellow;
#         }    #T_578bbc94_d30e_11e8_b2b6_52540011a660row6_col4 {
#             background-color:  yellow;
#         }    #T_578bbc94_d30e_11e8_b2b6_52540011a660row6_col10 {
#             background-color:  yellow;
#         }    #T_578bbc94_d30e_11e8_b2b6_52540011a660row6_col11 {
#             background-color:  yellow;
#         }    #T_578bbc94_d30e_11e8_b2b6_52540011a660row6_col13 {
#             background-color:  yellow;
#         }    #T_578bbc94_d30e_11e8_b2b6_52540011a660row6_col17 {
#             background-color:  yellow;
#         }    #T_578bbc94_d30e_11e8_b2b6_52540011a660row6_col19 {
#             background-color:  yellow;
#         }    #T_578bbc94_d30e_11e8_b2b6_52540011a660row6_col20 {
#             background-color:  yellow;
#         }    #T_578bbc94_d30e_11e8_b2b6_52540011a660row6_col22 {
#             background-color:  yellow;
#         }    #T_578bbc94_d30e_11e8_b2b6_52540011a660row6_col27 {
#             background-color:  yellow;
#         }    #T_578bbc94_d30e_11e8_b2b6_52540011a660row6_col28 {
#             background-color:  yellow;
#         }    #T_578bbc94_d30e_11e8_b2b6_52540011a660row7_col0 {
#             background-color:  yellow;
#         }    #T_578bbc94_d30e_11e8_b2b6_52540011a660row7_col2 {
#             background-color:  yellow;
#         }    #T_578bbc94_d30e_11e8_b2b6_52540011a660row7_col3 {
#             background-color:  yellow;
#         }    #T_578bbc94_d30e_11e8_b2b6_52540011a660row7_col6 {
#             background-color:  yellow;
#         }    #T_578bbc94_d30e_11e8_b2b6_52540011a660row7_col7 {
#             background-color:  yellow;
#         }    #T_578bbc94_d30e_11e8_b2b6_52540011a660row7_col9 {
#             background-color:  yellow;
#         }    #T_578bbc94_d30e_11e8_b2b6_52540011a660row7_col14 {
#             background-color:  yellow;
#         }    #T_578bbc94_d30e_11e8_b2b6_52540011a660row7_col21 {
#             background-color:  yellow;
#         }    #T_578bbc94_d30e_11e8_b2b6_52540011a660row7_col25 {
#             background-color:  yellow;
#         }    #T_578bbc94_d30e_11e8_b2b6_52540011a660row7_col30 {
#             background-color:  yellow;
#         }    #T_578bbc94_d30e_11e8_b2b6_52540011a660row9_col12 {
#             background-color:  yellow;
#         }    #T_578bbc94_d30e_11e8_b2b6_52540011a660row10_col5 {
#             background-color:  yellow;
#         }    #T_578bbc94_d30e_11e8_b2b6_52540011a660row10_col24 {
#             background-color:  yellow;
#         }    #T_578bbc94_d30e_11e8_b2b6_52540011a660row10_col29 {
#             background-color:  yellow;
#         }    #T_578bbc94_d30e_11e8_b2b6_52540011a660row11_col16 {
#             background-color:  yellow;
#         }    #T_578bbc94_d30e_11e8_b2b6_52540011a660row11_col23 {
#             background-color:  yellow;
#         }</style>
# <table id="T_578bbc94_d30e_11e8_b2b6_52540011a660" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#         <th class="col_heading level0 col3" >4</th>
#         <th class="col_heading level0 col4" >5</th>
#         <th class="col_heading level0 col5" >6</th>
#         <th class="col_heading level0 col6" >7</th>
#         <th class="col_heading level0 col7" >8</th>
#         <th class="col_heading level0 col8" >9</th>
#         <th class="col_heading level0 col9" >10</th>
#         <th class="col_heading level0 col10" >11</th>
#         <th class="col_heading level0 col11" >12</th>
#         <th class="col_heading level0 col12" >13</th>
#         <th class="col_heading level0 col13" >14</th>
#         <th class="col_heading level0 col14" >15</th>
#         <th class="col_heading level0 col15" >16</th>
#         <th class="col_heading level0 col16" >17</th>
#         <th class="col_heading level0 col17" >18</th>
#         <th class="col_heading level0 col18" >19</th>
#         <th class="col_heading level0 col19" >20</th>
#         <th class="col_heading level0 col20" >21</th>
#         <th class="col_heading level0 col21" >22</th>
#         <th class="col_heading level0 col22" >23</th>
#         <th class="col_heading level0 col23" >24</th>
#         <th class="col_heading level0 col24" >25</th>
#         <th class="col_heading level0 col25" >26</th>
#         <th class="col_heading level0 col26" >27</th>
#         <th class="col_heading level0 col27" >28</th>
#         <th class="col_heading level0 col28" >29</th>
#         <th class="col_heading level0 col29" >30</th>
#         <th class="col_heading level0 col30" >31</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_578bbc94_d30e_11e8_b2b6_52540011a660level0_row0" class="row_heading level0 row0" >CLIP</th>
#         <td id="T_578bbc94_d30e_11e8_b2b6_52540011a660row0_col0" class="data row0 col0" >0.86261</td>
#         <td id="T_578bbc94_d30e_11e8_b2b6_52540011a660row0_col1" class="data row0 col1" >0.722053</td>
#         <td id="T_578bbc94_d30e_11e8_b2b6_52540011a660row0_col2" class="data row0 col2" >0.699819</td>
#         <td id="T_578bbc94_d30e_11e8_b2b6_52540011a660row0_col3" class="data row0 col3" >0.716765</td>
#         <td id="T_578bbc94_d30e_11e8_b2b6_52540011a660row0_col4" class="data row0 col4" >0.66645</td>
#         <td id="T_578bbc94_d30e_11e8_b2b6_52540011a660row0_col5" class="data row0 col5" >0.739097</td>
#         <td id="T_578bbc94_d30e_11e8_b2b6_52540011a660row0_col6" class="data row0 col6" >0.798115</td>
#         <td id="T_578bbc94_d30e_11e8_b2b6_52540011a660row0_col7" class="data row0 col7" >0.821919</td>
#         <td id="T_578bbc94_d30e_11e8_b2b6_52540011a660row0_col8" class="data row0 col8" >0.703788</td>
#         <td id="T_578bbc94_d30e_11e8_b2b6_52540011a660row0_col9" class="data row0 col9" >0.899806</td>
#         <td id="T_578bbc94_d30e_11e8_b2b6_52540011a660row0_col10" class="data row0 col10" >0.897527</td>
#         <td id="T_578bbc94_d30e_11e8_b2b6_52540011a660row0_col11" class="data row0 col11" >0.821902</td>
#         <td id="T_578bbc94_d30e_11e8_b2b6_52540011a660row0_col12" class="data row0 col12" >0.639843</td>
#         <td id="T_578bbc94_d30e_11e8_b2b6_52540011a660row0_col13" class="data row0 col13" >0.933989</td>
#         <td id="T_578bbc94_d30e_11e8_b2b6_52540011a660row0_col14" class="data row0 col14" >0.855171</td>
#         <td id="T_578bbc94_d30e_11e8_b2b6_52540011a660row0_col15" class="data row0 col15" >0.604067</td>
#         <td id="T_578bbc94_d30e_11e8_b2b6_52540011a660row0_col16" class="data row0 col16" >0.616279</td>
#         <td id="T_578bbc94_d30e_11e8_b2b6_52540011a660row0_col17" class="data row0 col17" >0.747053</td>
#         <td id="T_578bbc94_d30e_11e8_b2b6_52540011a660row0_col18" class="data row0 col18" >0.63889</td>
#         <td id="T_578bbc94_d30e_11e8_b2b6_52540011a660row0_col19" class="data row0 col19" >0.722152</td>
#         <td id="T_578bbc94_d30e_11e8_b2b6_52540011a660row0_col20" class="data row0 col20" >0.907397</td>
#         <td id="T_578bbc94_d30e_11e8_b2b6_52540011a660row0_col21" class="data row0 col21" >0.70034</td>
#         <td id="T_578bbc94_d30e_11e8_b2b6_52540011a660row0_col22" class="data row0 col22" >0.860709</td>
#         <td id="T_578bbc94_d30e_11e8_b2b6_52540011a660row0_col23" class="data row0 col23" >0.60608</td>
#         <td id="T_578bbc94_d30e_11e8_b2b6_52540011a660row0_col24" class="data row0 col24" >0.733086</td>
#         <td id="T_578bbc94_d30e_11e8_b2b6_52540011a660row0_col25" class="data row0 col25" >0.871429</td>
#         <td id="T_578bbc94_d30e_11e8_b2b6_52540011a660row0_col26" cl

# %%
iDeep = [0.90,0.73,0.91,0.91,0.74,0.94,0.97,0.96,0.68,0.94,0.97,0.95,0.92,0.97,0.95,0.93,0.97,0.82,0.82,0.79,0.97,0.87,0.98,0.95,0.92,0.97,0.89,0.94,0.92,0.95,0.92]
iONMF = [0.89,0.71,0.81,0.84,0.73,0.92,0.93,0.91,0.71,0.94,0.95,0.87,0.81,0.96,0.93,0.95,0.97,0.74,0.66,0.69,0.96,0.81,0.93,0.84,0.85,0.91,0.84,0.93,0.87,0.82,0.80]


d1 = np.subtract(score_fold, iDeep)
d2 = np.subtract(score_fold,iONMF)


n1 = sum(1 for number in d1 if number > 0)
n2 = sum(1 for number in d2 if number > 0)

print ("Mean difference with iDeep is %s " % (np.mean(d1)))
print ("Number of proteins for which our model is better: %s " % (n1))
print ("Mean difference with iONMF is %s " % (np.mean(d2)))
print ("Number of proteins for which our model is better: %s " % (n2))
# Out:
# Mean difference with iDeep is -0.011178479145073831
# Number of proteins for which our model is better: 11
# Mean difference with iONMF is 0.03946668214524874
# Number of proteins for which our model is better: 26

# %%
architecture2 = [0.9143333823348299, 0.7573013849834791, 0.9180967447519492, 0.923215600943046, 0.7330244995339836, 0.924588145393727, 0.9662741768269101, 0.964839231399187, 0.7550789614715081, 0.9409992583543163, 0.9357561729437043, 0.9363884594550672, 0.9053931160189969, 0.9803568396371108, 0.9467776425904786, 0.9258174752575057, 0.9504022401997088, 0.8121714150759602, 0.7697724368378708, 0.7998433198747424, 0.9746595550695856, 0.8535907177458295, 0.9784272913931946, 0.9451255069626996, 0.8877592338584328, 0.9663380723012309, 0.8965035762830261, 0.9360588783269976, 0.9251686576154574, 0.8992999986040914, 0.9212355487143704]
iDeep = [0.90,0.73,0.91,0.91,0.74,0.94,0.97,0.96,0.68,0.94,0.97,0.95,0.92,0.97,0.95,0.93,0.97,0.82,0.82,0.79,0.97,0.87,0.98,0.95,0.92,0.97,0.89,0.94,0.92,0.95,0.92]
iONMF = [0.89,0.71,0.81,0.84,0.73,0.92,0.93,0.91,0.71,0.94,0.95,0.87,0.81,0.96,0.93,0.95,0.97,0.74,0.66,0.69,0.96,0.81,0.93,0.84,0.85,0.91,0.84,0.93,0.87,0.82,0.80]


d1 = np.subtract(architecture2, iDeep)
d2 = np.subtract(architecture2,iONMF)


n1 = sum(1 for number in d1 if number > 0)
n2 = sum(1 for number in d2 if number > 0)

print ("Mean difference with iDeep is %s " % (np.mean(d1)))
print ("Number of proteins for which our model is better: %s " % (n1))
print ("Mean difference with iONMF is %s " % (np.mean(d2)))
print ("Number of proteins for which our model is better: %s " % (n2))


'''
Architecture used

model.add(Conv1D(60,6 ,data_format='channels_last', input_shape=(101, size) , strides = 1, padding='valid'))
        model.add(MaxPooling1D(pool_size=12, strides=2, padding='valid'))
        model.add(Conv1D(60, 4, activation='relu'))
        model.add(GlobalAveragePooling1D())
        model.add(Dense(200, activation='relu'))
        model.add(Dense(2, activation='sigmoid'))
        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])



        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]

        model.fit(X_train, y_train, epochs=10, batch_size=16, verbose=0)

'''
# Out:
# Mean difference with iDeep is -0.0034000793303548926
# Number of proteins for which our model is better: 13
# Mean difference with iONMF is 0.04724508195996768
# Number of proteins for which our model is better: 28

# %%
import pandas as pd
import numpy as np


architecture3 = [0.9248051792559911, 0.7601939295589869, 0.8931065628986852, 0.9243556367628045, 0.7407509744423812, 0.9300272269507298, 0.9724631045304635, 0.9633622595776907, 0.7338951176766474, 0.9325402381279408, 0.9337217910047257, 0.9456623900653638, 0.9156455554716594, 0.9826804349588105, 0.9421785208087151, 0.9383586993460458, 0.9511568778277038, 0.8139083964257703, 0.7701445158731476, 0.7995574122913112, 0.9744453119698194, 0.8565192238971531, 0.9799592664128515, 0.9530300132090638, 0.9034892170490118, 0.9697731705518853, 0.8896440960278632, 0.9395599601048404, 0.9342613974919534, 0.9184314288786833, 0.923151549124797]
iDeep = [0.90,0.73,0.91,0.91,0.74,0.94,0.97,0.96,0.68,0.94,0.97,0.95,0.92,0.97,0.95,0.93,0.97,0.82,0.82,0.79,0.97,0.87,0.98,0.95,0.92,0.97,0.89,0.94,0.92,0.95,0.92]
iONMF = [0.89,0.71,0.81,0.84,0.73,0.92,0.93,0.91,0.71,0.94,0.95,0.87,0.81,0.96,0.93,0.95,0.97,0.74,0.66,0.69,0.96,0.81,0.93,0.84,0.85,0.91,0.84,0.93,0.87,0.82,0.80]


d1 = np.subtract(architecture3, iDeep)
d2 = np.subtract(architecture3,iONMF)


n1 = sum(1 for number in d1 if number > 0)
n2 = sum(1 for number in d2 if number > 0)

print ("Mean difference with iDeep is %s " % (np.mean(d1)))
print ("Number of proteins for which our model is better: %s " % (n1))
print ("Mean difference with iONMF is %s " % (np.mean(d2)))
print ("Number of proteins for which our model is better: %s " % (n2))
'''
 model = Sequential()
        model.add(Conv1D(120,6 ,data_format='channels_last', input_shape=(101, size) , strides = 1, padding='valid'))
        model.add(MaxPooling1D(pool_size=20, strides=1, padding='valid'))
        model.add(Conv1D(60,4 , activation='relu'))
        model.add(MaxPooling1D(pool_size=10, strides=1, padding='valid'))
        model.add(Conv1D(30,4 , activation='relu'))
        model.add(GlobalAveragePooling1D())
        model.add(Dense(200, activation='relu'))
        model.add(Dense(2, activation='sigmoid'))
        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

'''
# Out:
# Mean difference with iDeep is -0.0012651787556936522
# Number of proteins for which our model is better: 14
# Mean difference with iONMF is 0.049379982534628906
# Number of proteins for which our model is better: 27

# %%
architecture = [0.9285116931149237, 0.7590753107081687, 0.9186283785334929, 0.9264152431969649, 0.7395972063075883, 0.9304200392104385, 0.9742056330336062, 0.9620228964156574, 0.7332097766523548, 0.9345647981546922, 0.9340894428886539, 0.9438880683583697, 0.9190235725154263, 0.9828313080202069, 0.9435348882640564, 0.9418003331333, 0.9572880299489961, 0.8013634540539567, 0.7717297850700696, 0.7987599828238954, 0.9740932129890039, 0.8650047490831823, 0.9801141003001078, 0.9542181444312453, 0.9028089883878565, 0.9713199777306825, 0.8870632198841217, 0.9336625267790166, 0.9349480341335674, 0.9186635968926058, 0.9241304313421382]
iDeep = [0.90,0.73,0.91,0.91,0.74,0.94,0.97,0.96,0.68,0.94,0.97,0.95,0.92,0.97,0.95,0.93,0.97,0.82,0.82,0.79,0.97,0.87,0.98,0.95,0.92,0.97,0.89,0.94,0.92,0.95,0.92]
iONMF = [0.89,0.71,0.81,0.84,0.73,0.92,0.93,0.91,0.71,0.94,0.95,0.87,0.81,0.96,0.93,0.95,0.97,0.74,0.66,0.69,0.96,0.81,0.93,0.84,0.85,0.91,0.84,0.93,0.87,0.82,0.80]


d1 = np.subtract(architecture, iDeep)
d2 = np.subtract(architecture,iONMF)


n1 = sum(1 for number in d1 if number > 0)
n2 = sum(1 for number in d2 if number > 0)

print ("Mean difference with iDeep is %s " % (np.mean(d1)))
print ("Number of proteins for which our model is better: %s " % (n1))
print ("Mean difference with iONMF is %s " % (np.mean(d2)))
print ("Number of proteins for which our model is better: %s " % (n2))

'''
model = Sequential()
        model.add(Conv1D(60,6 ,data_format='channels_last', input_shape=(101, size) , strides = 1, padding='valid'))
        model.add(MaxPooling1D(pool_size=20, strides=1, padding='valid'))
        model.add(Conv1D(60,4 , activation='relu'))
        model.add(MaxPooling1D(pool_size=10, strides=1, padding='valid'))
        model.add(Conv1D(30,4 , activation='relu'))
        model.add(GlobalAveragePooling1D())
        model.add(Dense(200, activation='relu'))
        model.add(Dense(2, activation='sigmoid'))
        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

'''
# Out:
# Mean difference with iDeep is -9.719927876300673e-05
# Number of proteins for which our model is better: 16
# Mean difference with iONMF is 0.05054796201155956
# Number of proteins for which our model is better: 27
# "\nmodel = Sequential()\n        model.add(Conv1D(60,6 ,data_format='channels_last', input_shape=(101, size) , strides = 1, padding='valid'))\n        model.add(MaxPooling1D(pool_size=20, strides=1, padding='valid'))\n        model.add(Conv1D(60,4 , activation='relu'))\n        model.add(MaxPooling1D(pool_size=10, strides=1, padding='valid'))\n        model.add(Conv1D(30,4 , activation='relu'))\n        model.add(GlobalAveragePooling1D())\n        model.add(Dense(200, activation='relu'))\n        model.add(Dense(2, activation='sigmoid'))\n        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])\n\n"

# %%
architecture = [0.9258816232137577, 0.7649756048240798, 0.9196456882443131, 0.925817382746527, 0.7426969662704102, 0.9355114003815194, 0.9731856118644672, 0.9642261572629597, 0.7339809503464924, 0.9357227704802813, 0.9356815092494024, 0.9399670419850438, 0.9180934705962646, 0.9818644564162777, 0.9448661989282646, 0.9420408328292471, 0.9558399590097005, 0.813024884302467, 0.7759749528751211, 0.7975623024114464, 0.9755726482847586, 0.851693650456486, 0.9818478289150485, 0.954992978746781, 0.9025681592749111, 0.9725026768383227, 0.8915800841503325, 0.9446363635955137, 0.9323881293759811, 0.9173351299243944, 0.9296042594317935]
iDeep = [0.90,0.73,0.91,0.91,0.74,0.94,0.97,0.96,0.68,0.94,0.97,0.95,0.92,0.97,0.95,0.93,0.97,0.82,0.82,0.79,0.97,0.87,0.98,0.95,0.92,0.97,0.89,0.94,0.92,0.95,0.92]
iONMF = [0.89,0.71,0.81,0.84,0.73,0.92,0.93,0.91,0.71,0.94,0.95,0.87,0.81,0.96,0.93,0.95,0.97,0.74,0.66,0.69,0.96,0.81,0.93,0.84,0.85,0.91,0.84,0.93,0.87,0.82,0.80]


d1 = np.subtract(architecture, iDeep)
d2 = np.subtract(architecture,iONMF)


n1 = sum(1 for number in d1 if number > 0)
n2 = sum(1 for number in d2 if number > 0)

print ("Mean difference with iDeep is %s " % (np.mean(d1)))
print ("Number of proteins for which our model is better: %s " % (n1))
print ("Mean difference with iONMF is %s " % (np.mean(d2)))
print ("Number of proteins for which our model is better: %s " % (n2))
'''
 model = Sequential()
        model.add(Conv1D(60,6 ,data_format='channels_last', input_shape=(101, size) , strides = 1, padding='valid'))
        model.add(MaxPooling1D(pool_size=20, strides=1, padding='valid'))
        model.add(Conv1D(30,4 , activation='relu'))
        model.add(MaxPooling1D(pool_size=10, strides=1, padding='valid'))
        model.add(Conv1D(30,4 , activation='relu'))
        model.add(GlobalAveragePooling1D())
        model.add(Dense(200, activation='relu'))
        model.add(Dense(2, activation='sigmoid'))
        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])



        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]

        model.fit(X_train, y_train, epochs=10, batch_size=16, verbose=0)

'''
# Out:
# Mean difference with iDeep is 0.0010090862333021423
# Number of proteins for which our model is better: 19
# Mean difference with iONMF is 0.0516542475236247
# Number of proteins for which our model is better: 27
# "\n model = Sequential()\n        model.add(Conv1D(60,6 ,data_format='channels_last', input_shape=(101, size) , strides = 1, padding='valid'))\n        model.add(MaxPooling1D(pool_size=20, strides=1, padding='valid'))\n        model.add(Conv1D(30,4 , activation='relu'))\n        model.add(MaxPooling1D(pool_size=10, strides=1, padding='valid'))\n        model.add(Conv1D(30,4 , activation='relu'))\n        model.add(GlobalAveragePooling1D())\n        model.add(Dense(200, activation='relu'))\n        model.add(Dense(2, activation='sigmoid'))\n        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])\n\n\n\n        X_train, X_test = X[train_index], X[test_index]\n        y_train, y_test = y[train_index], y[test_index]\n\n        model.fit(X_train, y_train, epochs=10, batch_size=16, verbose=0)\n\n"

# %%
#parameters in the first layer
nin = 101 #number of features
p = 0 #convolution padding size
k = 6 #convolution kernel size
s = 1 #convolution stride size
jin = 1 #jump (distance between two consecutive features)
rin = 1 #receprive field size

# Receptive Field Arithmetic
nout = ((nin+2*p-k)/s)+1
jout = jin*s
rout = rin +(k-1)*jin

print ('conv1',nout, jout, rout)


#parameters for each of the following layers
layers = ['pool1','conv2','pool2','conv3','pool3','conv4']

ki = [20,4,40,4,30,3]
i = 0

# Receptive Field Arithmetic
for layer in layers:
    
    nin = nout
    jin = jout
    rin = rout
    k = ki[i]

    nout = ((nin+2*p-k)/s)+1
    jout = jin*s
    rout = rin +(k-1)*jin
    
    i = i+1
    
    print (layer,nout, jout, rout)
# Out:
# ('conv1', 96, 1, 6)
# ('pool1', 77, 1, 25)
# ('conv2', 74, 1, 28)
# ('pool2', 35, 1, 67)
# ('conv3', 32, 1, 70)
# ('pool3', 3, 1, 99)
# ('conv4', 1, 1, 101)

# %%
architecture = [0.9307442375298661, 0.7624816309090088, 0.9169902333989197, 0.9235353546852576, 0.7371032726708908, 0.9349053830333917, 0.9699650720773192, 0.9620923801611871, 0.7439610803717309, 0.930055038380719, 0.9218240337803284, 0.95149442900164, 0.9362829092106022, 0.9858136032002026, 0.9451665553626443, 0.9467591102923668, 0.9667672328526423, 0.8098868876678397, 0.7753656901207704, 0.7986567480068447, 0.9709792605316009, 0.8487226041483324, 0.9786711582054064, 0.9581547310894143, 0.9059760227333233, 0.9778682003145981, 0.8943681304176225, 0.9433842290901978, 0.9342015852604473, 0.9370546345833315, 0.934342049464146]
iDeep = [0.90,0.73,0.91,0.91,0.74,0.94,0.97,0.96,0.68,0.94,0.97,0.95,0.92,0.97,0.95,0.93,0.97,0.82,0.82,0.79,0.97,0.87,0.98,0.95,0.92,0.97,0.89,0.94,0.92,0.95,0.92]
iONMF = [0.89,0.71,0.81,0.84,0.73,0.92,0.93,0.91,0.71,0.94,0.95,0.87,0.81,0.96,0.93,0.95,0.97,0.74,0.66,0.69,0.96,0.81,0.93,0.84,0.85,0.91,0.84,0.93,0.87,0.82,0.80]


d1 = np.subtract(architecture, iDeep)
d2 = np.subtract(architecture,iONMF)


n1 = sum(1 for number in d1 if number > 0)
n2 = sum(1 for number in d2 if number > 0)

print ("Mean difference with iDeep is %s " % (np.mean(d1)))
print ("Number of proteins for which our model is better: %s " % (n1))
print ("Mean difference with iONMF is %s " % (np.mean(d2)))
print ("Number of proteins for which our model is better: %s " % (n2))
'''
 # sestavljanje modela
        model = Sequential()
        model.add(Conv1D(60,6 ,data_format='channels_last', input_shape=(101, size) , strides = 1, padding='valid'))
        model.add(MaxPooling1D(pool_size=20, strides=1, padding='valid'))
        model.add(Conv1D(30,4 , activation='relu'))
        model.add(MaxPooling1D(pool_size=40, strides=1, padding='valid'))
        model.add(Conv1D(30,4 , activation='relu'))
        model.add(MaxPooling1D(pool_size=30, strides=1, padding='valid'))
        model.add(Conv1D(30,2 , activation='relu'))
        model.add(GlobalAveragePooling1D())

        model.add(Dense(200, activation='relu'))
        model.add(Dense(2, activation='sigmoid'))
        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

'''
# Out:
# Mean difference with iDeep is 0.002695918985567525
# Number of proteins for which our model is better: 18
# Mean difference with iONMF is 0.0533410802758901
# Number of proteins for which our model is better: 27
# "\n # sestavljanje modela\n        model = Sequential()\n        model.add(Conv1D(60,6 ,data_format='channels_last', input_shape=(101, size) , strides = 1, padding='valid'))\n        model.add(MaxPooling1D(pool_size=20, strides=1, padding='valid'))\n        model.add(Conv1D(30,4 , activation='relu'))\n        model.add(MaxPooling1D(pool_size=40, strides=1, padding='valid'))\n        model.add(Conv1D(30,4 , activation='relu'))\n        model.add(MaxPooling1D(pool_size=30, strides=1, padding='valid'))\n        model.add(Conv1D(30,2 , activation='relu'))\n        model.add(GlobalAveragePooling1D())\n\n        model.add(Dense(200, activation='relu'))\n        model.add(Dense(2, activation='sigmoid'))\n        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])\n\n"

# %%
architecture = [0.8887681382216929, 0.742459207801405, 0.8776884977937744, 0.8951033292395429, 0.7284377952118877, 0.90383645426159, 0.9435809209945086, 0.9586649671484061, 0.7105055043556255, 0.9399050643140076, 0.9378822576152146, 0.9406129621364478, 0.9247286768825094, 0.9683301952346343, 0.9288579454731096, 0.9370165690305683, 0.9613048684771826, 0.8101787364851056, 0.7639451574845959, 0.7618145930379191, 0.9592091451532878, 0.6912663811649665, 0.973785969321604, 0.9540210883706577, 0.8970442345668058, 0.9683618781770684, 0.8892322488499073, 0.9343813553912165, 0.9076112227001877, 0.8851174622276601, 0.8595697848403654]
iDeep = [0.90,0.73,0.91,0.91,0.74,0.94,0.97,0.96,0.68,0.94,0.97,0.95,0.92,0.97,0.95,0.93,0.97,0.82,0.82,0.79,0.97,0.87,0.98,0.95,0.92,0.97,0.89,0.94,0.92,0.95,0.92]
iONMF = [0.89,0.71,0.81,0.84,0.73,0.92,0.93,0.91,0.71,0.94,0.95,0.87,0.81,0.96,0.93,0.95,0.97,0.74,0.66,0.69,0.96,0.81,0.93,0.84,0.85,0.91,0.84,0.93,0.87,0.82,0.80]


d1 = np.subtract(architecture, iDeep)
d2 = np.subtract(architecture,iONMF)


n1 = sum(1 for number in d1 if number > 0)
n2 = sum(1 for number in d2 if number > 0)

print ("Mean difference with iDeep is %s " % (np.mean(d1)))
print ("Number of proteins for which our model is better: %s " % (n1))
print ("Mean difference with iONMF is %s " % (np.mean(d2)))
print ("Number of proteins for which our model is better: %s " % (n2))


'''
sestavljanje modela
model = Sequential()
model.add(Conv1D(60,6 ,data_format='channels_last', input_shape=(101, size) , strides = 1, padding='valid'))
model.add(Dropout(0.5))
model.add(MaxPooling1D(pool_size=20, strides=1, padding='valid'))
model.add(Conv1D(30,4 , activation='relu'))
model.add(MaxPooling1D(pool_size=40, strides=1, padding='valid'))
model.add(Conv1D(30,4 , activation='relu'))
model.add(MaxPooling1D(pool_size=30, strides=1, padding='valid'))
model.add(Conv1D(30,2 , activation='relu'))
model.add(GlobalAveragePooling1D())

model.add(Dense(200, activation='relu'))
model.add(Dense(2, activation='sigmoid'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])



X_train, X_test = X[train_index], X[test_index]
y_train, y_test = y[train_index], y[test_index]

model.fit(X_train, y_train, epochs=10, batch_size=16, verbose=0)
'''
# Out:
# Mean difference with iDeep is -0.01957346413021112
# Number of proteins for which our model is better: 5
# Mean difference with iONMF is 0.031071697160111454
# Number of proteins for which our model is better: 21
# "\nsestavljanje modela\nmodel = Sequential()\nmodel.add(Conv1D(60,6 ,data_format='channels_last', input_shape=(101, size) , strides = 1, padding='valid'))\nmodel.add(Dropout(0.5))\nmodel.add(MaxPooling1D(pool_size=20, strides=1, padding='valid'))\nmodel.add(Conv1D(30,4 , activation='relu'))\nmodel.add(MaxPooling1D(pool_size=40, strides=1, padding='valid'))\nmodel.add(Conv1D(30,4 , activation='relu'))\nmodel.add(MaxPooling1D(pool_size=30, strides=1, padding='valid'))\nmodel.add(Conv1D(30,2 , activation='relu'))\nmodel.add(GlobalAveragePooling1D())\n\nmodel.add(Dense(200, activation='relu'))\nmodel.add(Dense(2, activation='sigmoid'))\n\nmodel.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])\n\n\n\nX_train, X_test = X[train_index], X[test_index]\ny_train, y_test = y[train_index], y[test_index]\n\nmodel.fit(X_train, y_train, epochs=10, batch_size=16, verbose=0)\n"

# %%
architecture = [0.9234525211267656, 0.7604081411842095, 0.9224530910136126, 0.9254365173261776, 0.7430583028837792, 0.9295822767653672, 0.9743744330832449, 0.962355424319591, 0.7500014545226059, 0.9317625213803972, 0.9332625535127408, 0.9466261435488708, 0.9387019662194611, 0.9829091753192338, 0.94533610611792, 0.9415980459399143, 0.9652411991932027, 0.8054035750856258, 0.7594565475083546, 0.8000868079706536, 0.9693298790665359, 0.828279207969579, 0.9814748432670454, 0.9647599474343448, 0.9102561174382281, 0.9801060659856382, 0.8906228463800023, 0.9375685465906635, 0.9379369020763733, 0.9387248608212915, 0.9348595312836802]
iDeep = [0.90,0.73,0.91,0.91,0.74,0.94,0.97,0.96,0.68,0.94,0.97,0.95,0.92,0.97,0.95,0.93,0.97,0.82,0.82,0.79,0.97,0.87,0.98,0.95,0.92,0.97,0.89,0.94,0.92,0.95,0.92]
iONMF = [0.89,0.71,0.81,0.84,0.73,0.92,0.93,0.91,0.71,0.94,0.95,0.87,0.81,0.96,0.93,0.95,0.97,0.74,0.66,0.69,0.96,0.81,0.93,0.84,0.85,0.91,0.84,0.93,0.87,0.82,0.80]


d1 = np.subtract(architecture, iDeep)
d2 = np.subtract(architecture,iONMF)


n1 = sum(1 for number in d1 if number > 0)
n2 = sum(1 for number in d2 if number > 0)

print ("Mean difference with iDeep is %s " % (np.mean(d1)))
print ("Number of proteins for which our model is better: %s " % (n1))
print ("Mean difference with iONMF is %s " % (np.mean(d2)))
print ("Number of proteins for which our model is better: %s " % (n2))

'''
 model = Sequential()
        model.add(Conv1D(60,6 ,data_format='channels_last', input_shape=(101, size) , strides = 1, padding='valid'))

        model.add(MaxPooling1D(pool_size=20, strides=1, padding='valid'))
        model.add(Conv1D(60,4 , activation='relu'))
        model.add(Dropout(0.5))

        model.add(MaxPooling1D(pool_size=40, strides=1, padding='valid'))
        model.add(Conv1D(30,4 , activation='relu'))
        model.add(MaxPooling1D(pool_size=30, strides=1, padding='valid'))
        model.add(Conv1D(30,2 , activation='relu'))
        model.add(GlobalAveragePooling1D())
        
        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])



        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]

        model.fit(X_train, y_train, epochs=10, batch_size=16, verbose=0)

'''
# Out:
# Mean difference with iDeep is 0.0021105016882293636
# Number of proteins for which our model is better: 18
# Mean difference with iONMF is 0.05275566297855193
# Number of proteins for which our model is better: 27

# %%
import numpy as np
import pandas as pd
architecture = [0.9311219679978245, 0.7638349588583528, 0.9203322176713394, 0.917850068426026, 0.7360635808247241, 0.9333226372529773, 0.971487382282513, 0.964425281295638, 0.7434087336484962, 0.9364091492073839, 0.9297364477795768, 0.950879211156086, 0.9321938611235433, 0.9840665620900146, 0.9453494703843838, 0.9389876880376159, 0.9635828869926693, 0.8074946795130048, 0.7783207337762404, 0.8009098389384659, 0.9705215513432643, 0.8525051574441889, 0.9787078706552652, 0.9648610513847418, 0.907699318890956, 0.9782219709770068, 0.8950307499905439, 0.9390171415296719, 0.9401595269360865, 0.9385509195803821, 0.9305776052368419]
iDeep = [0.90,0.73,0.91,0.91,0.74,0.94,0.97,0.96,0.68,0.94,0.97,0.95,0.92,0.97,0.95,0.93,0.97,0.82,0.82,0.79,0.97,0.87,0.98,0.95,0.92,0.97,0.89,0.94,0.92,0.95,0.92]
iONMF = [0.89,0.71,0.81,0.84,0.73,0.92,0.93,0.91,0.71,0.94,0.95,0.87,0.81,0.96,0.93,0.95,0.97,0.74,0.66,0.69,0.96,0.81,0.93,0.84,0.85,0.91,0.84,0.93,0.87,0.82,0.80]


d1 = np.subtract(architecture, iDeep)
d2 = np.subtract(architecture,iONMF)


n1 = sum(1 for number in d1 if number > 0)
n2 = sum(1 for number in d2 if number > 0)

print ("Mean difference with iDeep is %s " % (np.mean(d1)))
print ("Number of proteins for which our model is better: %s " % (n1))
print ("Mean difference with iONMF is %s " % (np.mean(d2)))
print ("Number of proteins for which our model is better: %s " % (n2))

'''
    model = Sequential()
    model.add(Conv1D(60,6 ,data_format='channels_last', input_shape=(101, size) , strides = 1, padding='valid'))
    model.add(MaxPooling1D(pool_size=20, strides=1, padding='valid'))
    model.add(Conv1D(30,4 , activation='relu'))
    model.add(Dropout(0.5))
    model.add(MaxPooling1D(pool_size=40, strides=1, padding='valid'))
    model.add(Conv1D(30,4 , activation='relu'))
    model.add(MaxPooling1D(pool_size=30, strides=1, padding='valid'))
    model.add(Conv1D(30,2 , activation='relu'))
    model.add(GlobalAveragePooling1D())

    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])



    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    model.fit(X_train, y_train, epochs=10, batch_size=16, verbose=0)
        
'''
# Out:
# Mean difference with iDeep is 0.0030848458459943723
# Number of proteins for which our model is better: 18
# Mean difference with iONMF is 0.05373000713631693
# Number of proteins for which our model is better: 27
# "\n    model = Sequential()\n    model.add(Conv1D(60,6 ,data_format='channels_last', input_shape=(101, size) , strides = 1, padding='valid'))\n    model.add(MaxPooling1D(pool_size=20, strides=1, padding='valid'))\n    model.add(Conv1D(30,4 , activation='relu'))\n    model.add(Dropout(0.5))\n    model.add(MaxPooling1D(pool_size=40, strides=1, padding='valid'))\n    model.add(Conv1D(30,4 , activation='relu'))\n    model.add(MaxPooling1D(pool_size=30, strides=1, padding='valid'))\n    model.add(Conv1D(30,2 , activation='relu'))\n    model.add(GlobalAveragePooling1D())\n\n    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])\n\n\n\n    X_train, X_test = X[train_index], X[test_index]\n    y_train, y_test = y[train_index], y[test_index]\n\n    model.fit(X_train, y_train, epochs=10, batch_size=16, verbose=0)\n        \n"

# %%
import numpy as np
import pandas as pd
architecture = [0.9303918242938181, 0.7669881226514081, 0.9253083214204288, 0.9163121867505627, 0.7377335717132673, 0.9399386027333811, 0.9769618928691239, 0.9631795661481876, 0.7309079757775289, 0.933136995638671, 0.9308715223045916, 0.9501876783628374, 0.931236152668189, 0.9845018766948173, 0.945497496288335, 0.9416739422541737, 0.966791815994732, 0.8030398655497238, 0.7743138766995863, 0.7994812702699547, 0.97071954036776, 0.8564967746365346, 0.98050953363027, 0.9594867981401819, 0.9050336161131988, 0.976789114212346, 0.8897966481735224, 0.9470172859746462, 0.9351873717090466, 0.9355193400860339, 0.9321267639842029]
iDeep = [0.90,0.73,0.91,0.91,0.74,0.94,0.97,0.96,0.68,0.94,0.97,0.95,0.92,0.97,0.95,0.93,0.97,0.82,0.82,0.79,0.97,0.87,0.98,0.95,0.92,0.97,0.89,0.94,0.92,0.95,0.92]
iONMF = [0.89,0.71,0.81,0.84,0.73,0.92,0.93,0.91,0.71,0.94,0.95,0.87,0.81,0.96,0.93,0.95,0.97,0.74,0.66,0.69,0.96,0.81,0.93,0.84,0.85,0.91,0.84,0.93,0.87,0.82,0.80]


d1 = np.subtract(architecture, iDeep)
d2 = np.subtract(architecture,iONMF)


n1 = sum(1 for number in d1 if number > 0)
n2 = sum(1 for number in d2 if number > 0)

print ("Mean difference with iDeep is %s " % (np.mean(d1)))
print ("Number of proteins for which our model is better: %s " % (n1))
print ("Mean difference with iONMF is %s " % (np.mean(d2)))
print ("Number of proteins for which our model is better: %s " % (n2))

'''
    model = Sequential()
    model.add(Conv1D(60,6 ,data_format='channels_last', input_shape=(101, size) , strides = 1, padding='valid'))
    model.add(MaxPooling1D(pool_size=20, strides=1, padding='valid'))
    model.add(Conv1D(30,4 , activation='relu'))
    model.add(MaxPooling1D(pool_size=40, strides=1, padding='valid'))
    model.add(Conv1D(30,4 , activation='relu'))
    model.add(Dropout(0.5))
    model.add(MaxPooling1D(pool_size=30, strides=1, padding='valid'))
    model.add(Conv1D(30,2 , activation='relu'))
    model.add(GlobalAveragePooling1D())

    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])



    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    model.fit(X_train, y_train, epochs=10, batch_size=16, verbose=0)
        
'''
# Out:
# Mean difference with iDeep is 0.0028108820680987742
# Number of proteins for which our model is better: 19
# Mean difference with iONMF is 0.05345604335842135
# Number of proteins for which our model is better: 27
# "\n    model = Sequential()\n    model.add(Conv1D(60,6 ,data_format='channels_last', input_shape=(101, size) , strides = 1, padding='valid'))\n    model.add(MaxPooling1D(pool_size=20, strides=1, padding='valid'))\n    model.add(Conv1D(30,4 , activation='relu'))\n    model.add(MaxPooling1D(pool_size=40, strides=1, padding='valid'))\n    model.add(Conv1D(30,4 , activation='relu'))\n    model.add(Dropout(0.5))\n    model.add(MaxPooling1D(pool_size=30, strides=1, padding='valid'))\n    model.add(Conv1D(30,2 , activation='relu'))\n    model.add(GlobalAveragePooling1D())\n\n    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])\n\n\n\n    X_train, X_test = X[train_index], X[test_index]\n    y_train, y_test = y[train_index], y[test_index]\n\n    model.fit(X_train, y_train, epochs=10, batch_size=16, verbose=0)\n        \n"

# %%
import pandas as pd
import numpy as np

def highlight_max(s):
    '''
    Marks the series in bold.
    '''
    is_max = s == s.max()
    return ['font-weight:bold' if v else '' for v in is_max]


architecture = [0.9311219679978245, 0.7638349588583528, 0.9203322176713394, 0.917850068426026, 0.7360635808247241, 0.9333226372529773, 0.971487382282513, 0.964425281295638, 0.7434087336484962, 0.9364091492073839, 0.9297364477795768, 0.950879211156086, 0.9321938611235433, 0.9840665620900146, 0.9453494703843838, 0.9389876880376159, 0.9635828869926693, 0.8074946795130048, 0.7783207337762404, 0.8009098389384659, 0.9705215513432643, 0.8525051574441889, 0.9787078706552652, 0.9648610513847418, 0.907699318890956, 0.9782219709770068, 0.8950307499905439, 0.9390171415296719, 0.9401595269360865, 0.9385509195803821, 0.9305776052368419]
iDeep = [0.90,0.73,0.91,0.91,0.74,0.94,0.97,0.96,0.68,0.94,0.97,0.95,0.92,0.97,0.95,0.93,0.97,0.82,0.82,0.79,0.97,0.87,0.98,0.95,0.92,0.97,0.89,0.94,0.92,0.95,0.92]
iONMF = [0.89,0.71,0.81,0.84,0.73,0.92,0.93,0.91,0.71,0.94,0.95,0.87,0.81,0.96,0.93,0.95,0.97,0.74,0.66,0.69,0.96,0.81,0.93,0.84,0.85,0.91,0.84,0.93,0.87,0.82,0.80]


architecture = np.round(architecture,decimals =2)


protein_list = ["1_PARCLIP_AGO1234_hg19", "2_PARCLIP_AGO2MNASE_hg19","3_HITSCLIP_Ago2_binding_clusters","4_HITSCLIP_Ago2_binding_clusters_2","5_CLIPSEQ_AGO2_hg19", "6_CLIP-seq-eIF4AIII_1","7_CLIP-seq-eIF4AIII_2","8_PARCLIP_ELAVL1_hg19","9_PARCLIP_ELAVL1MNASE_hg19", "10_PARCLIP_ELAVL1A_hg19", "10_PARCLIP_ELAVL1A_hg19", "12_PARCLIP_EWSR1_hg19", "13_PARCLIP_FUS_hg19", "14_PARCLIP_FUS_mut_hg19", "15_PARCLIP_IGF2BP123_hg19", "16_ICLIP_hnRNPC_Hela_iCLIP_all_clusters", "17_ICLIP_HNRNPC_hg19", "18_ICLIP_hnRNPL_Hela_group_3975_all-hnRNPL-Hela-hg19_sum_G_hg19--ensembl59_from_2337-2339-741_bedGraph-cDNA-hits-in-genome", "19_ICLIP_hnRNPL_U266_group_3986_all-hnRNPL-U266-hg19_sum_G_hg19--ensembl59_from_2485_bedGraph-cDNA-hits-in-genome", "20_ICLIP_hnRNPlike_U266_group_4000_all-hnRNPLlike-U266-hg19_sum_G_hg19--ensembl59_from_2342-2486_bedGraph-cDNA-hits-in-genome", "21_PARCLIP_MOV10_Sievers_hg19", "22_ICLIP_NSUN2_293_group_4007_all-NSUN2-293-hg19_sum_G_hg19--ensembl59_from_3137-3202_bedGraph-cDNA-hits-in-genome", "23_PARCLIP_PUM2_hg19", "24_PARCLIP_QKI_hg19", "25_CLIPSEQ_SFRS1_hg19","26_PARCLIP_TAF15_hg19", "27_ICLIP_TDP43_hg19", "28_ICLIP_TIA1_hg19", "29_ICLIP_TIAL1_hg19", "30_ICLIP_U2AF65_Hela_iCLIP_ctrl_all_clusters", "31_ICLIP_U2AF65_Hela_iCLIP_ctrl+kd_all_clusters"]
protein_list = np.arange(1,32,1)

              
table_data = {'New':architecture,'iDeep': iDeep,'iONMF':iONMF}

table = pd.DataFrame(table_data, index = protein_list)
table = table.T


table.style.apply(highlight_max)
# Out:
# <style  type="text/css" >
#     #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col0 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col1 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col2 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col3 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col4 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col6 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col7 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col8 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col9 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col11 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col12 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col13 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col14 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col19 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col20 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col22 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col23 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col25 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col26 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col27 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col28 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col30 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row1_col4 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row1_col5 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row1_col6 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row1_col7 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row1_col9 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row1_col10 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row1_col11 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row1_col14 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row1_col16 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row1_col17 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row1_col18 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row1_col20 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row1_col21 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row1_col22 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row1_col24 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row1_col27 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row1_col29 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row2_col9 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row2_col15 {
#             font-weight: bold;
#         }    #T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row2_col16 {
#             font-weight: bold;
#         }</style>
# <table id="T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#         <th class="col_heading level0 col3" >4</th>
#         <th class="col_heading level0 col4" >5</th>
#         <th class="col_heading level0 col5" >6</th>
#         <th class="col_heading level0 col6" >7</th>
#         <th class="col_heading level0 col7" >8</th>
#         <th class="col_heading level0 col8" >9</th>
#         <th class="col_heading level0 col9" >10</th>
#         <th class="col_heading level0 col10" >11</th>
#         <th class="col_heading level0 col11" >12</th>
#         <th class="col_heading level0 col12" >13</th>
#         <th class="col_heading level0 col13" >14</th>
#         <th class="col_heading level0 col14" >15</th>
#         <th class="col_heading level0 col15" >16</th>
#         <th class="col_heading level0 col16" >17</th>
#         <th class="col_heading level0 col17" >18</th>
#         <th class="col_heading level0 col18" >19</th>
#         <th class="col_heading level0 col19" >20</th>
#         <th class="col_heading level0 col20" >21</th>
#         <th class="col_heading level0 col21" >22</th>
#         <th class="col_heading level0 col22" >23</th>
#         <th class="col_heading level0 col23" >24</th>
#         <th class="col_heading level0 col24" >25</th>
#         <th class="col_heading level0 col25" >26</th>
#         <th class="col_heading level0 col26" >27</th>
#         <th class="col_heading level0 col27" >28</th>
#         <th class="col_heading level0 col28" >29</th>
#         <th class="col_heading level0 col29" >30</th>
#         <th class="col_heading level0 col30" >31</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660level0_row0" class="row_heading level0 row0" >New</th>
#         <td id="T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col0" class="data row0 col0" >0.93</td>
#         <td id="T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col1" class="data row0 col1" >0.76</td>
#         <td id="T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col2" class="data row0 col2" >0.92</td>
#         <td id="T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col3" class="data row0 col3" >0.92</td>
#         <td id="T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col4" class="data row0 col4" >0.74</td>
#         <td id="T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col5" class="data row0 col5" >0.93</td>
#         <td id="T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col6" class="data row0 col6" >0.97</td>
#         <td id="T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col7" class="data row0 col7" >0.96</td>
#         <td id="T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col8" class="data row0 col8" >0.74</td>
#         <td id="T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col9" class="data row0 col9" >0.94</td>
#         <td id="T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col10" class="data row0 col10" >0.93</td>
#         <td id="T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col11" class="data row0 col11" >0.95</td>
#         <td id="T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col12" class="data row0 col12" >0.93</td>
#         <td id="T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col13" class="data row0 col13" >0.98</td>
#         <td id="T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col14" class="data row0 col14" >0.95</td>
#         <td id="T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col15" class="data row0 col15" >0.94</td>
#         <td id="T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col16" class="data row0 col16" >0.96</td>
#         <td id="T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col17" class="data row0 col17" >0.81</td>
#         <td id="T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col18" class="data row0 col18" >0.78</td>
#         <td id="T_5a2cf6e2_ecc3_11e8_b2b6_52540011a660row0_col19" class="data row0 c

# %%
np.mean(architecture)
# Out:
# 0.9083870967741936

# %%
#https://medium.com/mlreview/a-guide-to-receptive-field-arithmetic-for-convolutional-neural-networks-e0f514068807


#parameters in the first layer
nin = 101 #number of features
p = 2 #convolution padding size
k = 5 #convolution kernel size
s = 1 #convolution stride size
jin = 1 #jump (distance between two consecutive features)
rin = 1 #receprive field size

# Receptive Field Arithmetic
nout = ((nin+2*p-k)/s)+1
jout = jin*s
rout = rin +(k-1)*jin

print ('conv1',nout, jout, rout)


#parameters for each of the following layers
layers = ['conv2','conv3','conv4','conv5','pool1','conv6']

ki = [4,30,4,4,4,2]
si = [1,4,1,1,3,1]
i = 0
p = 0
# Receptive Field Arithmetic
for layer in layers:
    
    nin = nout
    jin = jout
    rin = rout
    k = ki[i]
    s = si[i]

    nout = ((nin+2*p-k)/s)+1
    jout = jin*s
    rout = rin +(k-1)*jin
    
    i = i+1
    
    print (layer,nout, jout, rout)
# Out:
# ('conv1', 101, 1, 5)
# ('conv2', 98, 1, 8)
# ('conv3', 18, 4, 37)
# ('conv4', 15, 4, 49)
# ('conv5', 12, 4, 61)
# ('pool1', 3, 12, 73)
# ('conv6', 2, 12, 85)

# %%
import pandas as pd
import numpy as np

def highlight_max(s):
    '''
    Marks the series in bold.
    '''
    is_max = s == s.max()
    return ['font-weight:bold' if v else '' for v in is_max]

architecture = [0.9291983335024707, 0.7651499592158268, 0.9287091265729263, 0.9234442244802304, 0.7364646663463134, 0.9353502000683374, 0.9751938377733049, 0.9635168229108272, 0.7480441636087577, 0.9346671614887399, 0.9334940249230028, 0.949523263169057, 0.9276532222938382, 0.9852166482163515, 0.9429690477664376, 0.945769948595989, 0.9649891702394129, 0.8007685826907235, 0.7732648235421152, 0.8027100113919463, 0.9707501513101737, 0.8550998884527516, 0.977862995508198, 0.9581364300124371, 0.9094462929636776, 0.9795481269712912, 0.8983216973834953, 0.9443326220617765, 0.9323671533365572, 0.9373046668621641, 0.9277661869459333]
iDeep = [0.90,0.73,0.91,0.91,0.74,0.94,0.97,0.96,0.68,0.94,0.97,0.95,0.92,0.97,0.95,0.93,0.97,0.82,0.82,0.79,0.97,0.87,0.98,0.95,0.92,0.97,0.89,0.94,0.92,0.95,0.92]
iONMF = [0.89,0.71,0.81,0.84,0.73,0.92,0.93,0.91,0.71,0.94,0.95,0.87,0.81,0.96,0.93,0.95,0.97,0.74,0.66,0.69,0.96,0.81,0.93,0.84,0.85,0.91,0.84,0.93,0.87,0.82,0.80]


architecture = np.round(architecture,decimals =2)


protein_list = ["1_PARCLIP_AGO1234_hg19", "2_PARCLIP_AGO2MNASE_hg19","3_HITSCLIP_Ago2_binding_clusters","4_HITSCLIP_Ago2_binding_clusters_2","5_CLIPSEQ_AGO2_hg19", "6_CLIP-seq-eIF4AIII_1","7_CLIP-seq-eIF4AIII_2","8_PARCLIP_ELAVL1_hg19","9_PARCLIP_ELAVL1MNASE_hg19", "10_PARCLIP_ELAVL1A_hg19", "10_PARCLIP_ELAVL1A_hg19", "12_PARCLIP_EWSR1_hg19", "13_PARCLIP_FUS_hg19", "14_PARCLIP_FUS_mut_hg19", "15_PARCLIP_IGF2BP123_hg19", "16_ICLIP_hnRNPC_Hela_iCLIP_all_clusters", "17_ICLIP_HNRNPC_hg19", "18_ICLIP_hnRNPL_Hela_group_3975_all-hnRNPL-Hela-hg19_sum_G_hg19--ensembl59_from_2337-2339-741_bedGraph-cDNA-hits-in-genome", "19_ICLIP_hnRNPL_U266_group_3986_all-hnRNPL-U266-hg19_sum_G_hg19--ensembl59_from_2485_bedGraph-cDNA-hits-in-genome", "20_ICLIP_hnRNPlike_U266_group_4000_all-hnRNPLlike-U266-hg19_sum_G_hg19--ensembl59_from_2342-2486_bedGraph-cDNA-hits-in-genome", "21_PARCLIP_MOV10_Sievers_hg19", "22_ICLIP_NSUN2_293_group_4007_all-NSUN2-293-hg19_sum_G_hg19--ensembl59_from_3137-3202_bedGraph-cDNA-hits-in-genome", "23_PARCLIP_PUM2_hg19", "24_PARCLIP_QKI_hg19", "25_CLIPSEQ_SFRS1_hg19","26_PARCLIP_TAF15_hg19", "27_ICLIP_TDP43_hg19", "28_ICLIP_TIA1_hg19", "29_ICLIP_TIAL1_hg19", "30_ICLIP_U2AF65_Hela_iCLIP_ctrl_all_clusters", "31_ICLIP_U2AF65_Hela_iCLIP_ctrl+kd_all_clusters"]
protein_list = np.arange(1,32,1)

              
table_data = {'New':architecture,'iDeep': iDeep,'iONMF':iONMF}

table = pd.DataFrame(table_data, index = protein_list)
table = table.T


table.style.apply(highlight_max)

d1 = np.subtract(architecture, iDeep)
d2 = np.subtract(architecture,iONMF)


n1 = sum(1 for number in d1 if number > 0)
n2 = sum(1 for number in d2 if number > 0)

print ("Mean difference with iDeep is %s " % (np.mean(d1)))
print ("Number of proteins for which our model is better: %s " % (n1))
print ("Mean difference with iONMF is %s " % (np.mean(d2)))
print ("Number of proteins for which our model is better: %s " % (n2))

'''
        model = Sequential()
        model.add(Conv1D(60,6 ,data_format='channels_last', input_shape=(101, size) , strides = 1, padding='valid'))
        model.add(MaxPooling1D(pool_size=20, strides=1, padding='valid'))
        model.add(Conv1D(60,4 , activation='relu'))
        model.add(Dropout(0.2))
        model.add(MaxPooling1D(pool_size=40, strides=1, padding='valid'))
        model.add(Conv1D(60,4 , activation='relu'))
        model.add(MaxPooling1D(pool_size=30, strides=1, padding='valid'))
        model.add(Conv1D(60,3 , activation='relu'))
        model.add(GlobalAveragePooling1D())


        model.add(Dense(200, activation='relu'))
        model.add(Dense(2, activation='sigmoid'))

        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

'''


table.style.apply(highlight_max)
# Out:
# Mean difference with iDeep is 0.0038709677419354943
# Number of proteins for which our model is better: 15
# Mean difference with iONMF is 0.05451612903225806
# Number of proteins for which our model is better: 27
# <style  type="text/css" >
#     #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col0 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col1 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col2 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col3 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col4 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col5 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col6 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col7 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col8 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col11 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col12 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col13 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col15 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col19 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col20 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col22 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col23 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col25 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col26 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col27 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col28 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col30 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row1_col4 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row1_col5 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row1_col7 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row1_col9 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row1_col10 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row1_col11 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row1_col14 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row1_col16 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row1_col17 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row1_col18 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row1_col20 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row1_col21 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row1_col22 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row1_col24 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row1_col27 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row1_col29 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row2_col9 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row2_col15 {
#             font-weight: bold;
#         }    #T_60cd3c58_f0a8_11e8_b2b6_52540011a660row2_col16 {
#             font-weight: bold;
#         }</style>
# <table id="T_60cd3c58_f0a8_11e8_b2b6_52540011a660" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#         <th class="col_heading level0 col3" >4</th>
#         <th class="col_heading level0 col4" >5</th>
#         <th class="col_heading level0 col5" >6</th>
#         <th class="col_heading level0 col6" >7</th>
#         <th class="col_heading level0 col7" >8</th>
#         <th class="col_heading level0 col8" >9</th>
#         <th class="col_heading level0 col9" >10</th>
#         <th class="col_heading level0 col10" >11</th>
#         <th class="col_heading level0 col11" >12</th>
#         <th class="col_heading level0 col12" >13</th>
#         <th class="col_heading level0 col13" >14</th>
#         <th class="col_heading level0 col14" >15</th>
#         <th class="col_heading level0 col15" >16</th>
#         <th class="col_heading level0 col16" >17</th>
#         <th class="col_heading level0 col17" >18</th>
#         <th class="col_heading level0 col18" >19</th>
#         <th class="col_heading level0 col19" >20</th>
#         <th class="col_heading level0 col20" >21</th>
#         <th class="col_heading level0 col21" >22</th>
#         <th class="col_heading level0 col22" >23</th>
#         <th class="col_heading level0 col23" >24</th>
#         <th class="col_heading level0 col24" >25</th>
#         <th class="col_heading level0 col25" >26</th>
#         <th class="col_heading level0 col26" >27</th>
#         <th class="col_heading level0 col27" >28</th>
#         <th class="col_heading level0 col28" >29</th>
#         <th class="col_heading level0 col29" >30</th>
#         <th class="col_heading level0 col30" >31</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_60cd3c58_f0a8_11e8_b2b6_52540011a660level0_row0" class="row_heading level0 row0" >New</th>
#         <td id="T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col0" class="data row0 col0" >0.93</td>
#         <td id="T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col1" class="data row0 col1" >0.77</td>
#         <td id="T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col2" class="data row0 col2" >0.93</td>
#         <td id="T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col3" class="data row0 col3" >0.92</td>
#         <td id="T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col4" class="data row0 col4" >0.74</td>
#         <td id="T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col5" class="data row0 col5" >0.94</td>
#         <td id="T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col6" class="data row0 col6" >0.98</td>
#         <td id="T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col7" class="data row0 col7" >0.96</td>
#         <td id="T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col8" class="data row0 col8" >0.75</td>
#         <td id="T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col9" class="data row0 col9" >0.93</td>
#         <td id="T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col10" class="data row0 col10" >0.93</td>
#         <td id="T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col11" class="data row0 col11" >0.95</td>
#         <td id="T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col12" class="data row0 col12" >0.93</td>
#         <td id="T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col13" class="data row0 col13" >0.99</td>
#         <td id="T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col14" class="data row0 col14" >0.94</td>
#         <td id="T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col15" class="data row0 col15" >0.95</td>
#         <td id="T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col16" class="data row0 col16" >0.96</td>
#         <td id="T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col17" class="data row0 col17" >0.8</td>
#         <td id="T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col18" class="data row0 col18" >0.77</td>
#         <td id="T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col19" class="data row0 col19" >0.8</td>
#         <td id="T_60cd3c58_f0a8_11e8_b2b6_52540011a660row0_col20" class="data r

# %%
import pandas as pd
import numpy as np

def highlight_max(s):
    '''
    Marks the series in bold.
    '''
    is_max = s == s.max()
    return ['font-weight:bold' if v else '' for v in is_max]

architecture = 0.8985000000000001, 0.7460062500000001, 0.92445, 0.9375562500000001, 0.76429375, 0.9348249999999998, 0.97129375, 0.96374375, 0.7457812500000001, 0.9401437499999998, 0.9343875, 0.9669812499999999, 0.9281187500000001, 0.9791000000000001, 0.94618125, 0.9423312500000001, 0.9739062500000001, 0.7771187499999999, 0.68004375, 0.70166875, 0.97808125, 0.84450625, 0.99000625, 0.9641499999999998, 0.9241937499999999, 0.9778875, 0.8919750000000001, 0.96765625, 0.9282812500000002, 0.938475, 0.9336
iDeep = [0.90,0.73,0.91,0.91,0.74,0.94,0.97,0.96,0.68,0.94,0.97,0.95,0.92,0.97,0.95,0.93,0.97,0.82,0.82,0.79,0.97,0.87,0.98,0.95,0.92,0.97,0.89,0.94,0.92,0.95,0.92]
iONMF = [0.89,0.71,0.81,0.84,0.73,0.92,0.93,0.91,0.71,0.94,0.95,0.87,0.81,0.96,0.93,0.95,0.97,0.74,0.66,0.69,0.96,0.81,0.93,0.84,0.85,0.91,0.84,0.93,0.87,0.82,0.80]


architecture = np.round(architecture,decimals =2)


protein_list = ["1_PARCLIP_AGO1234_hg19", "2_PARCLIP_AGO2MNASE_hg19","3_HITSCLIP_Ago2_binding_clusters","4_HITSCLIP_Ago2_binding_clusters_2","5_CLIPSEQ_AGO2_hg19", "6_CLIP-seq-eIF4AIII_1","7_CLIP-seq-eIF4AIII_2","8_PARCLIP_ELAVL1_hg19","9_PARCLIP_ELAVL1MNASE_hg19", "10_PARCLIP_ELAVL1A_hg19", "10_PARCLIP_ELAVL1A_hg19", "12_PARCLIP_EWSR1_hg19", "13_PARCLIP_FUS_hg19", "14_PARCLIP_FUS_mut_hg19", "15_PARCLIP_IGF2BP123_hg19", "16_ICLIP_hnRNPC_Hela_iCLIP_all_clusters", "17_ICLIP_HNRNPC_hg19", "18_ICLIP_hnRNPL_Hela_group_3975_all-hnRNPL-Hela-hg19_sum_G_hg19--ensembl59_from_2337-2339-741_bedGraph-cDNA-hits-in-genome", "19_ICLIP_hnRNPL_U266_group_3986_all-hnRNPL-U266-hg19_sum_G_hg19--ensembl59_from_2485_bedGraph-cDNA-hits-in-genome", "20_ICLIP_hnRNPlike_U266_group_4000_all-hnRNPLlike-U266-hg19_sum_G_hg19--ensembl59_from_2342-2486_bedGraph-cDNA-hits-in-genome", "21_PARCLIP_MOV10_Sievers_hg19", "22_ICLIP_NSUN2_293_group_4007_all-NSUN2-293-hg19_sum_G_hg19--ensembl59_from_3137-3202_bedGraph-cDNA-hits-in-genome", "23_PARCLIP_PUM2_hg19", "24_PARCLIP_QKI_hg19", "25_CLIPSEQ_SFRS1_hg19","26_PARCLIP_TAF15_hg19", "27_ICLIP_TDP43_hg19", "28_ICLIP_TIA1_hg19", "29_ICLIP_TIAL1_hg19", "30_ICLIP_U2AF65_Hela_iCLIP_ctrl_all_clusters", "31_ICLIP_U2AF65_Hela_iCLIP_ctrl+kd_all_clusters"]
protein_list = np.arange(1,32,1)

              
table_data = {'New':architecture,'iDeep': iDeep,'iONMF':iONMF}

table = pd.DataFrame(table_data, index = protein_list)
table = table.T


table.style.apply(highlight_max)

d1 = np.subtract(architecture, iDeep)
d2 = np.subtract(architecture,iONMF)


n1 = sum(1 for number in d1 if number > 0)
n2 = sum(1 for number in d2 if number > 0)

print ("Mean difference with iDeep is %s " % (np.mean(d1)))
print ("Number of proteins for which our model is better: %s " % (n1))
print ("Mean difference with iONMF is %s " % (np.mean(d2)))
print ("Number of proteins for which our model is better: %s " % (n2))

'''
        model = Sequential()
        model.add(Conv1D(30,6 ,data_format='channels_last', input_shape=(101, size) , strides = 1, padding='valid'))
        model.add(MaxPooling1D(pool_size=20, strides=1, padding='valid'))
        model.add(Conv1D(30,4 , activation='relu'))
        model.add(Dropout(0.2))
        model.add(MaxPooling1D(pool_size=40, strides=1, padding='valid'))
        model.add(Conv1D(60,4 , activation='relu'))
        model.add(MaxPooling1D(pool_size=30, strides=1, padding='valid'))
        model.add(Conv1D(60,3 , activation='relu'))
        model.add(GlobalAveragePooling1D())


        model.add(Dense(100, activation='relu'))
        model.add(Dense(2, activation='sigmoid'))

        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

'''



table.style.apply(highlight_max)
# Out:
# Mean difference with iDeep is -0.0022580645161290273
# Number of proteins for which our model is better: 16
# Mean difference with iONMF is 0.04838709677419353
# Number of proteins for which our model is better: 27
# <style  type="text/css" >
#     #T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col0 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col1 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col2 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col3 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col4 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col6 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col7 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col8 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col9 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col11 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col12 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col13 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col14 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col16 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col20 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col22 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col23 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col24 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col25 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col26 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col27 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col28 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col30 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row1_col0 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row1_col5 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row1_col6 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row1_col7 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row1_col9 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row1_col10 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row1_col14 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row1_col16 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row1_col17 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row1_col18 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row1_col19 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row1_col21 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row1_col24 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row1_col26 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row1_col29 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row2_col9 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row2_col15 {
#             font-weight: bold;
#         }    #T_ce91eaa6_000a_11e9_b2b6_52540011a660row2_col16 {
#             font-weight: bold;
#         }</style>
# <table id="T_ce91eaa6_000a_11e9_b2b6_52540011a660" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#         <th class="col_heading level0 col3" >4</th>
#         <th class="col_heading level0 col4" >5</th>
#         <th class="col_heading level0 col5" >6</th>
#         <th class="col_heading level0 col6" >7</th>
#         <th class="col_heading level0 col7" >8</th>
#         <th class="col_heading level0 col8" >9</th>
#         <th class="col_heading level0 col9" >10</th>
#         <th class="col_heading level0 col10" >11</th>
#         <th class="col_heading level0 col11" >12</th>
#         <th class="col_heading level0 col12" >13</th>
#         <th class="col_heading level0 col13" >14</th>
#         <th class="col_heading level0 col14" >15</th>
#         <th class="col_heading level0 col15" >16</th>
#         <th class="col_heading level0 col16" >17</th>
#         <th class="col_heading level0 col17" >18</th>
#         <th class="col_heading level0 col18" >19</th>
#         <th class="col_heading level0 col19" >20</th>
#         <th class="col_heading level0 col20" >21</th>
#         <th class="col_heading level0 col21" >22</th>
#         <th class="col_heading level0 col22" >23</th>
#         <th class="col_heading level0 col23" >24</th>
#         <th class="col_heading level0 col24" >25</th>
#         <th class="col_heading level0 col25" >26</th>
#         <th class="col_heading level0 col26" >27</th>
#         <th class="col_heading level0 col27" >28</th>
#         <th class="col_heading level0 col28" >29</th>
#         <th class="col_heading level0 col29" >30</th>
#         <th class="col_heading level0 col30" >31</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_ce91eaa6_000a_11e9_b2b6_52540011a660level0_row0" class="row_heading level0 row0" >New</th>
#         <td id="T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col0" class="data row0 col0" >0.9</td>
#         <td id="T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col1" class="data row0 col1" >0.75</td>
#         <td id="T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col2" class="data row0 col2" >0.92</td>
#         <td id="T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col3" class="data row0 col3" >0.94</td>
#         <td id="T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col4" class="data row0 col4" >0.76</td>
#         <td id="T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col5" class="data row0 col5" >0.93</td>
#         <td id="T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col6" class="data row0 col6" >0.97</td>
#         <td id="T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col7" class="data row0 col7" >0.96</td>
#         <td id="T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col8" class="data row0 col8" >0.75</td>
#         <td id="T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col9" class="data row0 col9" >0.94</td>
#         <td id="T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col10" class="data row0 col10" >0.93</td>
#         <td id="T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col11" class="data row0 col11" >0.97</td>
#         <td id="T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col12" class="data row0 col12" >0.93</td>
#         <td id="T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col13" class="data row0 col13" >0.98</td>
#         <td id="T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col14" class="data row0 col14" >0.95</td>
#         <td id="T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col15" class="data row0 col15" >0.94</td>
#         <td id="T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col16" class="data row0 col16" >0.97</td>
#         <td id="T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col17" class="data row0 col17" >0.78</td>
#         <td id="T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col18" class="data row0 col18" >0.68</td>
#         <td id="T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col19" class="data row0 col19" >0.7</td>
#         <td id="T_ce91eaa6_000a_11e9_b2b6_52540011a660row0_col20" class="data ro

# %%
#results from 30k datasets

import pandas as pd
import numpy as np
from scipy import stats

def highlight_max(s):
    
    # applies bold style
    is_max = s == s.max()
    return ['font-weight:bold' if v else '' for v in is_max]


ionmf = [0.9 , 0.69, 0.82, 0.81, 0.65, 0.84, 0.89, 0.81, 0.66, 0.94, 0.93, 0.82, 0.59, 0.92, 0.91, 0.62, 0.61, 0.76, 0.63, 0.71, 0.96, 0.77, 0.91, 0.58, 0.84, 0.86, 0.61, 0.87, 0.8 , 0.67, 0.66]
ideep = [ 0.94,  0.76,  0.94,  0.94,  0.76,  0.96,  0.97,  0.96,  0.77, 0.95,  0.95,  0.95,  0.95,  0.99,  0.96,  0.95,  0.97,  0.85, 0.82,  0.83,  0.97,  0.89,  0.98,  0.97,  0.93,  0.98,  0.91, 0.95,  0.92,  0.95,  0.94]
new = [0.94, 0.76, 0.95, 0.95, 0.76, 0.96, 0.98, 0.97, 0.76, 0.93, 0.94, 0.96, 0.95, 0.99, 0.96, 0.96, 0.97, 0.86, 0.8 , 0.8 , 0.98, 0.87, 0.99, 0.98, 0.93, 0.98, 0.92, 0.98, 0.95, 0.96, 0.95]


protein_list = ["1_PARCLIP_AGO1234_hg19", "2_PARCLIP_AGO2MNASE_hg19","3_HITSCLIP_Ago2_binding_clusters","4_HITSCLIP_Ago2_binding_clusters_2","5_CLIPSEQ_AGO2_hg19", "6_CLIP-seq-eIF4AIII_1","7_CLIP-seq-eIF4AIII_2","8_PARCLIP_ELAVL1_hg19","9_PARCLIP_ELAVL1MNASE_hg19", "10_PARCLIP_ELAVL1A_hg19", "10_PARCLIP_ELAVL1A_hg19", "12_PARCLIP_EWSR1_hg19", "13_PARCLIP_FUS_hg19", "14_PARCLIP_FUS_mut_hg19", "15_PARCLIP_IGF2BP123_hg19", "16_ICLIP_hnRNPC_Hela_iCLIP_all_clusters", "17_ICLIP_HNRNPC_hg19", "18_ICLIP_hnRNPL_Hela_group_3975_all-hnRNPL-Hela-hg19_sum_G_hg19--ensembl59_from_2337-2339-741_bedGraph-cDNA-hits-in-genome", "19_ICLIP_hnRNPL_U266_group_3986_all-hnRNPL-U266-hg19_sum_G_hg19--ensembl59_from_2485_bedGraph-cDNA-hits-in-genome", "20_ICLIP_hnRNPlike_U266_group_4000_all-hnRNPLlike-U266-hg19_sum_G_hg19--ensembl59_from_2342-2486_bedGraph-cDNA-hits-in-genome", "21_PARCLIP_MOV10_Sievers_hg19", "22_ICLIP_NSUN2_293_group_4007_all-NSUN2-293-hg19_sum_G_hg19--ensembl59_from_3137-3202_bedGraph-cDNA-hits-in-genome", "23_PARCLIP_PUM2_hg19", "24_PARCLIP_QKI_hg19", "25_CLIPSEQ_SFRS1_hg19","26_PARCLIP_TAF15_hg19", "27_ICLIP_TDP43_hg19", "28_ICLIP_TIA1_hg19", "29_ICLIP_TIAL1_hg19", "30_ICLIP_U2AF65_Hela_iCLIP_ctrl_all_clusters", "31_ICLIP_U2AF65_Hela_iCLIP_ctrl+kd_all_clusters"]
protein_list = np.arange(1,32,1)

              
table_data = {'New':new,'iDeep': ideep,'iONMF':ionmf}
table = pd.DataFrame(table_data, index = protein_list)
table = table.T


table.style.apply(highlight_max)


d1 = np.subtract(new, ideep)
d2 = np.subtract(new,ionmf)


n1 = sum(1 for number in d1 if number > 0)
n2 = sum(1 for number in d2 if number > 0)


print ("Mean difference with iDeep is %s " % (np.mean(d1)))
print ("Number of proteins for which our model is better: %s " % (n1))
print ("Mean difference with iONMF is %s " % (np.mean(d2)))
print ("Number of proteins for which our model is better: %s " % (n2))


table.style.apply(highlight_max)

print(np.average(ionmf), stats.sem(ionmf))
print(np.average(ideep), stats.sem(ideep))
print(np.average(new), stats.sem(new))
# Out:
# Mean difference with iDeep is 0.002580645161290332
# Number of proteins for which our model is better: 15
# Mean difference with iONMF is 0.14838709677419354
# Number of proteins for which our model is better: 30
# (0.7754838709677421, 0.021755427994927055)
# (0.9212903225806451, 0.011938389649189972)
# (0.9238709677419356, 0.013015106354142585)

# %%
receptive_field = 0
receptive_field_previous = 1
filters = [6,20,4,40,4,30,3]
layers = ['conv1','pool1','conv2','pool2','conv3','pool3','conv4']

for i, filter_size in enumerate(filters):
    receptive_field = receptive_field_previous + filter_size - 1
    print('ERF of layer {} is {}'.format(layers[i], receptive_field))
    receptive_field_previous = receptive_field
# Out:
# ERF of layer conv1 is 6
# ERF of layer pool1 is 25
# ERF of layer conv2 is 28
# ERF of layer pool2 is 67
# ERF of layer conv3 is 70
# ERF of layer pool3 is 99
# ERF of layer conv4 is 101

# %%
import numpy as np
protein_list = ["1_PARCLIP_AGO1234_hg19", "2_PARCLIP_AGO2MNASE_hg19","3_HITSCLIP_Ago2_binding_clusters","4_HITSCLIP_Ago2_binding_clusters_2","5_CLIPSEQ_AGO2_hg19", "6_CLIP-seq-eIF4AIII_1","7_CLIP-seq-eIF4AIII_2","8_PARCLIP_ELAVL1_hg19","9_PARCLIP_ELAVL1MNASE_hg19", "10_PARCLIP_ELAVL1A_hg19", "10_PARCLIP_ELAVL1A_hg19", "12_PARCLIP_EWSR1_hg19", "13_PARCLIP_FUS_hg19", "14_PARCLIP_FUS_mut_hg19", "15_PARCLIP_IGF2BP123_hg19", "16_ICLIP_hnRNPC_Hela_iCLIP_all_clusters", "17_ICLIP_HNRNPC_hg19", "18_ICLIP_hnRNPL_Hela_group_3975_all-hnRNPL-Hela-hg19_sum_G_hg19--ensembl59_from_2337-2339-741_bedGraph-cDNA-hits-in-genome", "19_ICLIP_hnRNPL_U266_group_3986_all-hnRNPL-U266-hg19_sum_G_hg19--ensembl59_from_2485_bedGraph-cDNA-hits-in-genome", "20_ICLIP_hnRNPlike_U266_group_4000_all-hnRNPLlike-U266-hg19_sum_G_hg19--ensembl59_from_2342-2486_bedGraph-cDNA-hits-in-genome", "21_PARCLIP_MOV10_Sievers_hg19", "22_ICLIP_NSUN2_293_group_4007_all-NSUN2-293-hg19_sum_G_hg19--ensembl59_from_3137-3202_bedGraph-cDNA-hits-in-genome", "23_PARCLIP_PUM2_hg19", "24_PARCLIP_QKI_hg19", "25_CLIPSEQ_SFRS1_hg19","26_PARCLIP_TAF15_hg19", "27_ICLIP_TDP43_hg19", "28_ICLIP_TIA1_hg19", "29_ICLIP_TIAL1_hg19", "30_ICLIP_U2AF65_Hela_iCLIP_ctrl_all_clusters", "31_ICLIP_U2AF65_Hela_iCLIP_ctrl+kd_all_clusters"]
new = [0.94, 0.76, 0.95, 0.95, 0.76, 0.96, 0.98, 0.97, 0.76, 0.93, 0.94, 0.96, 0.95, 0.99, 0.96, 0.96, 0.97, 0.86, 0.8 , 0.8 , 0.98, 0.87, 0.99, 0.98, 0.93, 0.98, 0.92, 0.98, 0.95, 0.96, 0.95]
max_value = max(new)
max_protein = [protein_list[i] for i, j in enumerate(new) if j == max_value]
print (max_value, max_protein)

min_value = min(new)
min_protein = [protein_list[i] for i, j in enumerate(new) if j == min_value]
print (min_value, min_protein)

low_protein = [protein_list[i] for i, j in enumerate(new) if j > 0.9]
print (len(low_protein))
print (np.average(new))
# Out:
# (0.99, ['14_PARCLIP_FUS_mut_hg19', '23_PARCLIP_PUM2_hg19'])
# (0.76, ['2_PARCLIP_AGO2MNASE_hg19', '5_CLIPSEQ_AGO2_hg19', '9_PARCLIP_ELAVL1MNASE_hg19'])
# 24
# 0.9238709677419356
