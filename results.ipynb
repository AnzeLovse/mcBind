# %%
#results from 30k datasets

import pandas as pd
import numpy as np

def highlight_max(s):
    
    # applies bold style
    is_max = s == s.max()
    return ['font-weight:bold' if v else '' for v in is_max]


ionmf = [0.9 , 0.69, 0.82, 0.81, 0.65, 0.84, 0.89, 0.81, 0.66, 0.94, 0.93, 0.82, 0.59, 0.92, 0.91, 0.62, 0.61, 0.76, 0.63, 0.71, 0.96, 0.77, 0.91, 0.58, 0.84, 0.86, 0.61, 0.87, 0.8 , 0.67, 0.66]
ideep = [0.90,0.73,0.91,0.91,0.74,0.94,0.97,0.96,0.68,0.94,0.97,0.95,0.92,0.97,0.95,0.93,0.97,0.82,0.82,0.79,0.97,0.87,0.98,0.95,0.92,0.97,0.89,0.94,0.92,0.95,0.92]
#ideep = [0.94, 0.76, 0.94, 0.94, 0.76, 0.96, 0.97, 0.96, 0.77, 0.95, 0.95, 0.95, 0.95, 0.99, 0.96, 0.95, 0.97, 0.85, 0.82, 0.83, 0.97, 0.89, 0.98, 0.97, 0.93, 0.98, 0.91, 0.95, 0.92, 0.95, 0.94]
new = [0.94, 0.76, 0.95, 0.95, 0.76, 0.96, 0.98, 0.97, 0.76, 0.93, 0.94, 0.96, 0.95, 0.99, 0.96, 0.96, 0.97, 0.86, 0.8 , 0.8 , 0.98, 0.87, 0.99, 0.98, 0.93, 0.98, 0.92, 0.98, 0.95, 0.96, 0.95]


protein_list = ["1_PARCLIP_AGO1234_hg19", "2_PARCLIP_AGO2MNASE_hg19","3_HITSCLIP_Ago2_binding_clusters","4_HITSCLIP_Ago2_binding_clusters_2","5_CLIPSEQ_AGO2_hg19", "6_CLIP-seq-eIF4AIII_1","7_CLIP-seq-eIF4AIII_2","8_PARCLIP_ELAVL1_hg19","9_PARCLIP_ELAVL1MNASE_hg19", "10_PARCLIP_ELAVL1A_hg19", "10_PARCLIP_ELAVL1A_hg19", "12_PARCLIP_EWSR1_hg19", "13_PARCLIP_FUS_hg19", "14_PARCLIP_FUS_mut_hg19", "15_PARCLIP_IGF2BP123_hg19", "16_ICLIP_hnRNPC_Hela_iCLIP_all_clusters", "17_ICLIP_HNRNPC_hg19", "18_ICLIP_hnRNPL_Hela_group_3975_all-hnRNPL-Hela-hg19_sum_G_hg19--ensembl59_from_2337-2339-741_bedGraph-cDNA-hits-in-genome", "19_ICLIP_hnRNPL_U266_group_3986_all-hnRNPL-U266-hg19_sum_G_hg19--ensembl59_from_2485_bedGraph-cDNA-hits-in-genome", "20_ICLIP_hnRNPlike_U266_group_4000_all-hnRNPLlike-U266-hg19_sum_G_hg19--ensembl59_from_2342-2486_bedGraph-cDNA-hits-in-genome", "21_PARCLIP_MOV10_Sievers_hg19", "22_ICLIP_NSUN2_293_group_4007_all-NSUN2-293-hg19_sum_G_hg19--ensembl59_from_3137-3202_bedGraph-cDNA-hits-in-genome", "23_PARCLIP_PUM2_hg19", "24_PARCLIP_QKI_hg19", "25_CLIPSEQ_SFRS1_hg19","26_PARCLIP_TAF15_hg19", "27_ICLIP_TDP43_hg19", "28_ICLIP_TIA1_hg19", "29_ICLIP_TIAL1_hg19", "30_ICLIP_U2AF65_Hela_iCLIP_ctrl_all_clusters", "31_ICLIP_U2AF65_Hela_iCLIP_ctrl+kd_all_clusters"]
protein_list = np.arange(1,32,1)

              
table_data = {'New':new,'iDeep': ideep,'iONMF':ionmf}
table = pd.DataFrame(table_data, index = protein_list)
table = table.T


table.style.apply(highlight_max)


d1 = np.subtract(new, ideep)
d2 = np.subtract(new,ionmf)


n1 = sum(1 for number in d1 if number > 0)
n2 = sum(1 for number in d2 if number > 0)


print ("Mean difference with iDeep is %s " % (np.mean(d1)))
print ("Number of proteins for which our model is better: %s " % (n1))
print ("Mean difference with iONMF is %s " % (np.mean(d2)))
print ("Number of proteins for which our model is better: %s " % (n2))


table.style.apply(highlight_max)
# Out:
# Mean difference with iDeep is 0.002580645161290332
# Number of proteins for which our model is better: 15
# Mean difference with iONMF is 0.14838709677419354
# Number of proteins for which our model is better: 30
# <style  type="text/css" >
#     #T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col0 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col1 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col2 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col3 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col4 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col5 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col6 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col7 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col11 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col12 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col13 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col14 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col15 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col16 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col17 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col20 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col22 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col23 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col24 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col25 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col26 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col27 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col28 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col29 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col30 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row1_col0 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row1_col1 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row1_col4 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row1_col5 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row1_col8 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row1_col9 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row1_col10 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row1_col12 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row1_col13 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row1_col14 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row1_col16 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row1_col18 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row1_col19 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row1_col21 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row1_col24 {
#             font-weight: bold;
#         }    #T_ba51c546_284d_11e9_b56a_7572e00ecf43row1_col25 {
#             font-weight: bold;
#         }</style>
# <table id="T_ba51c546_284d_11e9_b56a_7572e00ecf43" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#         <th class="col_heading level0 col3" >4</th>
#         <th class="col_heading level0 col4" >5</th>
#         <th class="col_heading level0 col5" >6</th>
#         <th class="col_heading level0 col6" >7</th>
#         <th class="col_heading level0 col7" >8</th>
#         <th class="col_heading level0 col8" >9</th>
#         <th class="col_heading level0 col9" >10</th>
#         <th class="col_heading level0 col10" >11</th>
#         <th class="col_heading level0 col11" >12</th>
#         <th class="col_heading level0 col12" >13</th>
#         <th class="col_heading level0 col13" >14</th>
#         <th class="col_heading level0 col14" >15</th>
#         <th class="col_heading level0 col15" >16</th>
#         <th class="col_heading level0 col16" >17</th>
#         <th class="col_heading level0 col17" >18</th>
#         <th class="col_heading level0 col18" >19</th>
#         <th class="col_heading level0 col19" >20</th>
#         <th class="col_heading level0 col20" >21</th>
#         <th class="col_heading level0 col21" >22</th>
#         <th class="col_heading level0 col22" >23</th>
#         <th class="col_heading level0 col23" >24</th>
#         <th class="col_heading level0 col24" >25</th>
#         <th class="col_heading level0 col25" >26</th>
#         <th class="col_heading level0 col26" >27</th>
#         <th class="col_heading level0 col27" >28</th>
#         <th class="col_heading level0 col28" >29</th>
#         <th class="col_heading level0 col29" >30</th>
#         <th class="col_heading level0 col30" >31</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_ba51c546_284d_11e9_b56a_7572e00ecf43level0_row0" class="row_heading level0 row0" >New</th>
#         <td id="T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col0" class="data row0 col0" >0.94</td>
#         <td id="T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col1" class="data row0 col1" >0.76</td>
#         <td id="T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col2" class="data row0 col2" >0.95</td>
#         <td id="T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col3" class="data row0 col3" >0.95</td>
#         <td id="T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col4" class="data row0 col4" >0.76</td>
#         <td id="T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col5" class="data row0 col5" >0.96</td>
#         <td id="T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col6" class="data row0 col6" >0.98</td>
#         <td id="T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col7" class="data row0 col7" >0.97</td>
#         <td id="T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col8" class="data row0 col8" >0.76</td>
#         <td id="T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col9" class="data row0 col9" >0.93</td>
#         <td id="T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col10" class="data row0 col10" >0.94</td>
#         <td id="T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col11" class="data row0 col11" >0.96</td>
#         <td id="T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col12" class="data row0 col12" >0.95</td>
#         <td id="T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col13" class="data row0 col13" >0.99</td>
#         <td id="T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col14" class="data row0 col14" >0.96</td>
#         <td id="T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col15" class="data row0 col15" >0.96</td>
#         <td id="T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col16" class="data row0 col16" >0.97</td>
#         <td id="T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col17" class="data row0 col17" >0.86</td>
#         <td id="T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col18" class="data row0 col18" >0.8</td>
#         <td id="T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col19" class="data row0 col19" >0.8</td>
#         <td id="T_ba51c546_284d_11e9_b56a_7572e00ecf43row0_col20" class="data r
